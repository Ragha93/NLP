# %%
import numpy as np
import pandas as pd
import gensim,nltk,string,os,zipfile
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from gensim.models.word2vec import Word2Vec
import gensim.downloader as api
from nltk.stem import WordNetLemmatizer,PorterStemmer,LancasterStemmer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report,confusion_matrix

# %%
df = pd.read_csv('train.csv')

# %%
df['text']
# Out:
# 0       Our Deeds are the Reason of this #earthquake M...
# 1                  Forest fire near La Ronge Sask. Canada
# 2       All residents asked to 'shelter in place' are ...
# 3       13,000 people receive #wildfires evacuation or...
# 4       Just got sent this photo from Ruby #Alaska as ...
#                               ...
# 7608    Two giant cranes holding a bridge collapse int...
# 7609    @aria_ahrary @TheTawniest The out of control w...
# 7610    M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 7611    Police investigating after an e-bike collided ...
# 7612    The Latest: More Homes Razed by Northern Calif...
# Name: text, Length: 7613, dtype: object

# %%
[w for w in word_tokenize(df['text'].iloc[0]) if w not in stopwords.words('english')]
# Out:
# ['Our', 'Deeds', 'Reason', '#', 'earthquake', 'May', 'ALLAH', 'Forgive', 'us']

# %%
data = []
def text_cleaning(x):
    for i in x['text']:
        data.append([w for w in word_tokenize(i.lower()) if w not in stopwords.words('english') and w not in string.punctuation])

# %%
text_cleaning(df)

# %%
data
# Out:
# [['deeds', 'reason', 'earthquake', 'may', 'allah', 'forgive', 'us'],
#  ['forest', 'fire', 'near', 'la', 'ronge', 'sask', 'canada'],
#  ['residents',
#   'asked',
#   "'shelter",
#   'place',
#   'notified',
#   'officers',
#   'evacuation',
#   'shelter',
#   'place',
#   'orders',
#   'expected'],
#  ['13,000',
#   'people',
#   'receive',
#   'wildfires',
#   'evacuation',
#   'orders',
#   'california'],
#  ['got',
#   'sent',
#   'photo',
#   'ruby',
#   'alaska',
#   'smoke',
#   'wildfires',
#   'pours',
#   'school'],
#  ['rockyfire',
#   'update',
#   'california',
#   'hwy',
#   '20',
#   'closed',
#   'directions',
#   'due',
#   'lake',
#   'county',
#   'fire',
#   'cafire',
#   'wildfires'],
#  ['flood',
#   'disaster',
#   'heavy',
#   'rain',
#   'causes',
#   'flash',
#   'flooding',
#   'streets',
#   'manitou',
#   'colorado',
#   'springs',
#   'areas'],
#  ["'m", 'top', 'hill', 'see', 'fire', 'woods', '...'],
#  ["'s",
#   'emergency',
#   'evacuation',
#   'happening',
#   'building',
#   'across',
#   'street'],
#  ["'m", 'afraid', 'tornado', 'coming', 'area', '...'],
#  ['three', 'people', 'died', 'heat', 'wave', 'far'],
#  ['haha',
#   'south',
#   'tampa',
#   'getting',
#   'flooded',
#   'hah-',
#   'wait',
#   'second',
#   'live',
#   'south',
#   'tampa',
#   'gon',
#   'na',
#   'gon',
#   'na',
#   'fvck',
#   'flooding'],
#  ['raining',
#   'flooding',
#   'florida',
#   'tampabay',
#   'tampa',
#   '18',
#   '19',
#   'days',
#   "'ve",
#   'lost',
#   'count'],
#  ['flood', 'bago', 'myanmar', 'arrived', 'bago'],
#  ['damage', 'school', 'bus', '80', 'multi', 'car', 'crash', 'breaking'],
#  ["'s", 'man'],
#  ['love', 'fruits'],
#  ['summer', 'lovely'],
#  ['car', 'fast'],
#  ['goooooooaaaaaal'],
#  ['ridiculous', '....'],
#  ['london', 'cool'],
#  ['love', 'skiing'],
#  ['wonderful', 'day'],
#  ['looooool'],
#  ['way', '...', 'ca', "n't", 'eat', 'shit'],
#  ['nyc', 'last', 'week'],
#  ['love', 'girlfriend'],
#  ['cooool'],
#  ['like', 'pasta'],
#  ['end'],
#  ['bbcmtd', 'wholesale', 'markets', 'ablaze', 'http', '//t.co/lhyxeohy6c'],
#  ['always',
#   'try',
#   'bring',
#   'heavy',
#   'metal',
#   'rt',
#   'http',
#   '//t.co/yao1e0xngw'],
#  ['africanbaze',
#   'breaking',
#   'news',
#   'nigeria',
#   'flag',
#   'set',
#   'ablaze',
#   'aba',
#   'http',
#   '//t.co/2nndbgwyei'],
#  ['crying', 'set', 'ablaze'],
#  ['plus',
#   'side',
#   'look',
#   'sky',
#   'last',
#   'night',
#   'ablaze',
#   'http',
#   '//t.co/qqsmshaj3n'],
#  ['phdsquares',
#   'mufc',
#   "'ve",
#   'built',
#   'much',
#   'hype',
#   'around',
#   'new',
#   'acquisitions',
#   'doubt',
#   'set',
#   'epl',
#   'ablaze',
#   'season'],
#  ['inec', 'office', 'abia', 'set', 'ablaze', 'http', '//t.co/3imaomknna'],
#  ['barbados',
#   'bridgetown',
#   'jamaica',
#   '\x89ûò',
#   'two',
#   'cars',
#   'set',
#   'ablaze',
#   'santa',
#   'cruz',
#   '\x89ûó',
#   'head',
#   'st',
#   'elizabeth',
#   'police',
#   'superintende',
#   '...',
#   'http',
#   '//t.co/wdueaj8q4j'],
#  ['ablaze', 'lord'],
#  ['check',
#   'http',
#   '//t.co/roi2nsmejj',
#   'http',
#   '//t.co/3tj8zjin21',
#   'http',
#   '//t.co/yduixefipe',
#   'http',
#   '//t.co/lxtjc87kls',
#   'nsfw'],
#  ['outside', "'re", 'ablaze', 'alive', "'re", 'dead', 'inside'],
#  ['awesome',
#   'time',
#   'visiting',
#   'cfc',
#   'head',
#   'office',
#   'ancop',
#   'site',
#   'ablaze',
#   'thanks',
#   'tita',
#   'vida',
#   'taking',
#   'care',
#   'us'],
#  ['soooo', 'pumped', 'ablaze', 'southridgelife'],
#  ['wanted',
#   'set',
#   'chicago',
#   'ablaze',
#   'preaching',
#   '...',
#   'hotel',
#   'http',
#   '//t.co/o9qknbfofx'],
#  ['gained',
#   '3',
#   'followers',
#   'last',
#   'week',
#   'know',
#   'stats',
#   'grow',
#   'http',
#   '//t.co/tiyulif5c6'],
#  ['west',
#   'burned',
#   'thousands',
#   'wildfires',
#   'ablaze',
#   'california',
#   'alone',
#   'http',
#   '//t.co/vl5tbr3wbr'],
#  ['building', 'perfect', 'tracklist', 'life', 'leave', 'streets', 'ablaze'],
#  ['check',
#   'http',
#   '//t.co/roi2nsmejj',
#   'http',
#   '//t.co/3tj8zjin21',
#   'http',
#   '//t.co/yduixefipe',
#   'http',
#   '//t.co/lxtjc87kls',
#   'nsfw'],
#  ['first',
#   'night',
#   'retainers',
#   "'s",
#   'quite',
#   'weird',
#   'better',
#   'get',
#   'used',
#   'wear',
#   'every',
#   'single',
#   'night',
#   'next',
#   'year',
#   'least'],
#  ['deputies',
#   'man',
#   'shot',
#   'brighton',
#   'home',
#   'set',
#   'ablaze',
#   'http',
#   '//t.co/gwnrhmso8k'],
#  ['man',
#   'wife',
#   'get',
#   'six',
#   'years',
#   'jail',
#   'setting',
#   'ablaze',
#   'niece',
#   'http',
#   '//t.co/ev1ahoucza'],
#  ['santa',
#   'cruz',
#   '\x89ûó',
#   'head',
#   'st',
#   'elizabeth',
#   'police',
#   'superintendent',
#   'lanford',
#   'salmon',
#   'r',
#   '...',
#   'http',
#   '//t.co/vplr5hka2u',
#   'http',
#   '//t.co/sxhw2tnnlf'],
#  ['police',
#   'arsonist',
#   'deliberately',
#   'set',
#   'black',
#   'church',
#   'north',
#   'carolinaåêablaze',
#   'http',
#   '//t.co/pcxarbh9an'],
#  ['noches',
#   'el-bestia',
#   'alexis_sanchez',
#   'happy',
#   'see',
#   'teammates',
#   'training',
#   'hard',
#   'goodnight',
#   'gunners.',
#   'http',
#   '//t.co/uc4j4jhvgr'],
#  ['kurds',
#   'trampling',
#   'turkmen',
#   'flag',
#   'later',
#   'set',
#   'ablaze',
#   'others',
#   'vandalized',
#   'offices',
#   'turkmen',
#   'front',
#   'diyala',
#   'http',
#   '//t.co/4izfdyc3cg'],
#  ['truck',
#   'ablaze',
#   'r21',
#   'voortrekker',
#   'ave.',
#   'outside',
#   'tambo',
#   'intl',
#   'cargo',
#   'section',
#   'http',
#   '//t.co/8kscqkfkkf'],
#  ['set',
#   'hearts',
#   'ablaze',
#   'every',
#   'city',
#   'gift',
#   'every',
#   'skyline',
#   'like',
#   'kiss',
#   'upon',
#   'lips',
#   '\x89û_',
#   'https',
#   '//t.co/cyompz1a0z'],
#  ['sky',
#   'ablaze',
#   'tonight',
#   'los',
#   'angeles',
#   "'m",
#   'expecting',
#   'ig',
#   'fb',
#   'filled',
#   'sunset',
#   'shots',
#   'know',
#   'peeps'],
#  ['west',
#   'burned',
#   'thousands',
#   'wildfires',
#   'ablaze',
#   'california',
#   'alone',
#   'http',
#   '//t.co/icsjgz9te1',
#   'climate',
#   'energy',
#   'http',
#   '//t.co/9fxmn0l0bd'],
#  ['revel',
#   'wmv',
#   'videos',
#   'means',
#   'mac',
#   'farewell',
#   'ablaze',
#   'wmv',
#   'en',
#   'route',
#   'dvd',
#   'gtxrwm'],
#  ['progressive',
#   'greetings',
#   'month',
#   'students',
#   'would',
#   'set',
#   'pens',
#   'ablaze',
#   'torch',
#   'publications',
#   '...',
#   'http',
#   '//t.co/9fxpixqujt'],
#  ['rene',
#   'ablaze',
#   'amp',
#   'jacinta',
#   'secret',
#   '2k13',
#   'fallen',
#   'skies',
#   'edit',
#   'mar',
#   '30',
#   '2013',
#   'https',
#   '//t.co/7mlmsuzv1z'],
#  ['navista7',
#   'steve',
#   'fires',
#   'something',
#   'else',
#   'california',
#   'tinderbox',
#   'clown',
#   'setting',
#   "'hood",
#   'ablaze',
#   'news24680'],
#  ['nowplaying',
#   'rene',
#   'ablaze',
#   'amp',
#   'ian',
#   'buff',
#   'magnitude',
#   'http',
#   '//t.co/av2jsjfftc',
#   'edm'],
#  ['nxwestmidlands',
#   'huge',
#   'fire',
#   'wholesale',
#   'markets',
#   'ablaze',
#   'http',
#   '//t.co/rwzbfvnxer'],
#  ['ablaze', 'time', 'talk', 'go', "n't", 'know', 'make', 'due', 'work'],
#  ['ca',
#   "n't",
#   'kids',
#   'cuz',
#   'got',
#   'bicycle',
#   'accident',
#   'amp',
#   'split',
#   'testicles',
#   "'s",
#   'impossible',
#   'kids',
#   'michael',
#   'father'],
#  ['accident',
#   'i-24',
#   'w',
#   'nashvilletraffic',
#   'traffic',
#   'moving',
#   '8m',
#   'slower',
#   'usual',
#   'https',
#   '//t.co/0ghk693egj'],
#  ['accident',
#   'center',
#   'lane',
#   'blocked',
#   'santaclara',
#   'us-101',
#   'nb',
#   'great',
#   'america',
#   'pkwy',
#   'bayarea',
#   'traffic',
#   'http',
#   '//t.co/pmlohzurwr'],
#  ['http',
#   '//t.co/gkye6gjtk5',
#   'personalinjury',
#   'accident',
#   'summer',
#   'read',
#   'advice',
#   'amp',
#   'see',
#   'solicitor',
#   'help',
#   'otleyhour'],
#  ['stlouis',
#   'caraccidentlawyer',
#   'speeding',
#   'among',
#   'top',
#   'causes',
#   'teen',
#   'accidents',
#   'https',
#   '//t.co/k4zomof319',
#   'https',
#   '//t.co/s2kxvm0cba',
#   'car',
#   'accident',
#   'tee\x89û_'],
#  ['reported',
#   'motor',
#   'vehicle',
#   'accident',
#   'curry',
#   'herman',
#   'rd',
#   'near',
#   'stephenson',
#   'involving',
#   'overturned',
#   'vehicle',
#   'please',
#   'use',
#   '...',
#   'http',
#   '//t.co/ybjezkurw1'],
#  ['bigrigradio', 'live', 'accident', 'awareness'],
#  ['i-77',
#   'mile',
#   'marker',
#   '31',
#   'south',
#   'mooresville',
#   'iredell',
#   'vehicle',
#   'accident',
#   'ramp',
#   'closed',
#   '8/6',
#   '1:18',
#   'pm'],
#  ['rt',
#   'sleepjunkies',
#   'sleeping',
#   'pills',
#   'double',
#   'risk',
#   'car',
#   'accident',
#   'http',
#   '//t.co/7s9nm1fict'],
#  ["'by", 'accident', 'knew', 'gon', 'happen', 'https', '//t.co/ysxun5vceh'],
#  ['traffic',
#   'accident',
#   'n',
#   'cabrillo',
#   'hwy/magellan',
#   'av',
#   'mir',
#   '08/06/15',
#   '11:03:58'],
#  ['i-77',
#   'mile',
#   'marker',
#   '31',
#   '40',
#   'south',
#   'mooresville',
#   'iredell',
#   'vehicle',
#   'accident',
#   'congestion',
#   '8/6',
#   '1:18',
#   'pm'],
#  ['pastor', 'scene', 'accident', '......', 'owner', 'range', 'rover'],
#  ['mom',
#   "'we",
#   "n't",
#   'get',
#   'home',
#   'fast',
#   'wished',
#   "'why",
#   'mom',
#   "'there",
#   'accident',
#   'truck',
#   'spilt',
#   'mayonnaise'],
#  ['horrible',
#   'car',
#   'accident',
#   'past',
#   'sunday',
#   "'m",
#   'finally',
#   'able',
#   'get',
#   'around',
#   'thank',
#   'god'],
#  ['wait', 'see', 'pissed', 'donnie', 'tell', 'another', 'accident'],
#  ['truckcrash',
#   'overturns',
#   'fortworth',
#   'interstate',
#   'http',
#   '//t.co/rs22lj4qfp',
#   'click',
#   "'ve",
#   'crash',
#   'gt',
#   'http',
#   '//t.co/ld0uniyw4k'],
#  ['accident',
#   'ashville',
#   'us',
#   '23',
#   'sb',
#   'sr',
#   '752',
#   'traffic',
#   'http',
#   '//t.co/hylmo0wgfi'],
#  ['carolina',
#   'accident',
#   'motorcyclist',
#   'dies',
#   'i-540',
#   'crash',
#   'car',
#   'crossed',
#   'median',
#   'motorcycle',
#   'rider',
#   'traveling',
#   '...',
#   'http',
#   '//t.co/p18lzrlmy6'],
#  ['fyi',
#   'cad',
#   'fyi',
#   'accident',
#   'property',
#   'damage',
#   'nhs',
#   '999',
#   'piner',
#   'rd/horndale',
#   'dr'],
#  ['rt',
#   'naayf',
#   'first',
#   'accident',
#   'years',
#   'turning',
#   'onto',
#   'chandanee',
#   'magu',
#   'near',
#   'mma',
#   'taxi',
#   'rammed',
#   'halfway',
#   'turned',
#   'everyone',
#   'conf\x89û_'],
#  ['accident',
#   'left',
#   'lane',
#   'blocked',
#   'manchester',
#   'rt',
#   '293',
#   'nb',
#   'eddy',
#   'rd',
#   'stop',
#   'go',
#   'traffic',
#   'back',
#   'nh-3a',
#   'delay',
#   '4',
#   'mins',
#   'traffic'],
#  ['accident', 'property', 'damage', 'piner', 'rd/horndale', 'dr'],
#  ['accident', 'http', '//t.co/oia5fxi4gm'],
#  ['fyi',
#   'cad',
#   'fyi',
#   'accident',
#   'property',
#   'damage',
#   'wpd',
#   '1600',
#   '17th',
#   'st'],
#  ['8/6/2015',
#   '2:09',
#   'pm',
#   'traffic',
#   'accident',
#   'injury',
#   '2781',
#   'willis',
#   'foreman',
#   'rd',
#   'http',
#   '//t.co/vckit6edev'],
#  ['aashiqui',
#   'actress',
#   'anu',
#   'aggarwal',
#   'near-fatal',
#   'accident',
#   'http',
#   '//t.co/6otfp31lqw'],
#  ['suffield', 'alberta', 'accident', 'https', '//t.co/bptmlf4p10'],
#  ['9',
#   'mile',
#   'backup',
#   'i-77',
#   'south',
#   '...',
#   'accident',
#   'blocking',
#   'right',
#   '2',
#   'lanes',
#   'exit',
#   '31',
#   'langtree',
#   'rd',
#   '...',
#   'consider',
#   'nc',
#   '115',
#   'nc',
#   '150',
#   'nc',
#   '16',
#   'alternate'],
#  ['accident',
#   'changed',
#   'life',
#   'help',
#   'determine',
#   'options',
#   'financially',
#   'support',
#   'life',
#   'care',
#   'plans',
#   'on-going',
#   'treatment'],
#  ['breaking',
#   'deadly',
#   'motorcycle',
#   'car',
#   'accident',
#   'happened',
#   'hagerstown',
#   'today',
#   "'ll",
#   'details',
#   '5',
#   'your4state',
#   'whag'],
#  ['flowri', 'marinading', 'accident'],
#  ['car',
#   'even',
#   'week',
#   'got',
#   'fucking',
#   'car',
#   'accident',
#   '..',
#   'mfs',
#   'ca',
#   "n't",
#   'fucking',
#   'drive'],
#  ['norwaymfa',
#   'bahrain',
#   'police',
#   'previously',
#   'died',
#   'road',
#   'accident',
#   'killed',
#   'explosion',
#   'https',
#   '//t.co/gfjfgtodad'],
#  ['still',
#   'heard',
#   'church',
#   'leaders',
#   'kenya',
#   'coming',
#   'forward',
#   'comment',
#   'accident',
#   'issue',
#   'disciplinary',
#   'measures',
#   'arrestpastornganga'],
#  ['aftershock_delo', 'scuf', 'ps', 'live', 'game', '...', 'cya'],
#  ["'the",
#   'man',
#   'drive',
#   'effort',
#   'gets',
#   'painful',
#   'man',
#   'win',
#   'roger',
#   'bannister'],
#  ['320',
#   'ir',
#   'icemoon',
#   'aftershock',
#   'http',
#   '//t.co/ynxnvvkcda',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices\x89û_',
#   'http',
#   '//t.co/weqpesenku'],
#  ["'there",
#   'victory',
#   'bargain',
#   'basement',
#   'prices',
#   'dwight',
#   'david',
#   'eisenhower'],
#  ['320',
#   'ir',
#   'icemoon',
#   'aftershock',
#   'http',
#   '//t.co/vam5podgyw',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices\x89û_',
#   'http',
#   '//t.co/zevakjapcz'],
#  ["'nobody", 'remembers', 'came', 'second', 'charles', 'schulz'],
#  ['aftershock_delo',
#   'im',
#   'speaking',
#   'someone',
#   'using',
#   'scuf',
#   'xb1',
#   'people',
#   'end',
#   'getting',
#   'ps',
#   'also'],
#  ["'the", 'harder', 'conflict', 'glorious', 'triumph', 'thomas', 'paine'],
#  ['growingupspoiled',
#   'going',
#   'clay',
#   'pigeon',
#   'shooting',
#   'crying',
#   "'aftershock"],
#  ['guess', 'one', 'actually', 'wants', 'free', 'aftershock', 'tc', '.....'],
#  ['aftershock',
#   'terrifying',
#   'best',
#   'roller',
#   'coaster',
#   "'ve",
#   'ever',
#   'disclaimer',
#   "'ve"],
#  ['aftershock', 'https', '//t.co/xmwodfmtui'],
#  ['320',
#   'ir',
#   'icemoon',
#   'aftershock',
#   'http',
#   '//t.co/m4jdzmgjow',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices\x89û_',
#   'http',
#   '//t.co/n0uhasfkbv'],
#  ['320',
#   'ir',
#   'icemoon',
#   'aftershock',
#   'http',
#   '//t.co/vam5podgyw',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices\x89û_',
#   'http',
#   '//t.co/zevakjapcz'],
#  ['320',
#   'ir',
#   'icemoon',
#   'aftershock',
#   'http',
#   '//t.co/e14epzhoth',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices\x89û_',
#   'http',
#   '//t.co/22a9d5do6q'],
#  ['kjfordays', "'m", 'seeing', 'issues', 'aftershock'],
#  ['320',
#   'ir',
#   'icemoon',
#   'aftershock',
#   'http',
#   '//t.co/thyzomvwu0',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices\x89û_',
#   'http',
#   '//t.co/83joo0xk29'],
#  ['320',
#   'ir',
#   'icemoon',
#   'aftershock',
#   'http',
#   '//t.co/thyzomvwu0',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices\x89û_',
#   'http',
#   '//t.co/83joo0xk29'],
#  ['wisdomwed',
#   'bonus',
#   '5',
#   'minute',
#   'daily',
#   'habits',
#   'could',
#   'really',
#   'improve',
#   'life',
#   'many',
#   'already',
#   'lifehacks',
#   'http',
#   '//t.co/tbm9fqb8cw'],
#  ['aftershock',
#   'protect',
#   'profit',
#   'next',
#   'global',
#   'financial',
#   'meltdown',
#   'david',
#   'wiedemer',
#   'http',
#   'http',
#   '//t.co/wztz4hgmvq'],
#  ['moment',
#   'get',
#   'scary',
#   'roller',
#   'coaster',
#   'guy',
#   'behind',
#   'screaming',
#   'bloody',
#   'murder',
#   'silverwood',
#   'aftershock'],
#  ['aftershock',
#   '\x89ã¢',
#   '2010',
#   'full\x89ã¢',
#   'streaming',
#   'youtube',
#   'http',
#   '//t.co/vve3usesgf'],
#  ['gt',
#   'gt',
#   '15',
#   'aftershock',
#   'protect',
#   'profit',
#   'next',
#   'global',
#   'financial',
#   '...',
#   'book',
#   'http',
#   '//t.co/f6ntuc734z',
#   'esquireattire'],
#  ['sometimes',
#   'face',
#   'difficulties',
#   "'re",
#   'something',
#   'wrong',
#   "'re",
#   'something',
#   'right',
#   'joel',
#   'osteen'],
#  ["'the",
#   'thing',
#   'stands',
#   'dream',
#   'try',
#   'belief',
#   'actually',
#   'possible',
#   'joel',
#   'brown'],
#  ['praise',
#   'god',
#   'ministry',
#   'tells',
#   'like',
#   'wdyouth',
#   'biblestudy',
#   'https',
#   '//t.co/ujk0e5gbcc'],
#  ["'remembering",
#   'going',
#   'die',
#   'best',
#   'way',
#   'know',
#   'avoid',
#   'trap',
#   'thinking',
#   'something',
#   'lose',
#   '\x89ûò',
#   'steve',
#   'jobs'],
#  ['tried', 'orange', 'aftershock', 'today', 'life', 'never'],
#  ['onfireanders', 'love', 'bb'],
#  ['aftershock', 'https', '//t.co/jv8ppkhjy7'],
#  ['aftershock',
#   'back',
#   'school',
#   'kick',
#   'great',
#   'want',
#   'thank',
#   'everyone',
#   'making',
#   'possible',
#   'great',
#   'night'],
#  ['people', 'say', 'done', 'interrupt', '\x89ûò', 'george', 'bernard', 'shaw'],
#  ["'the",
#   'first',
#   'man',
#   'gets',
#   'oyster',
#   'second',
#   'man',
#   'gets',
#   'shell',
#   'andrew',
#   'carnegie'],
#  ['anyone',
#   'need',
#   'p/u',
#   'tonight',
#   'play',
#   'hybrid',
#   'slayer',
#   'ps4',
#   'eu',
#   'hmu',
#   'cod8sandscrims',
#   'empirikgaming',
#   'codawscrims',
#   '4tp_kotc',
#   '4tpfa',
#   'aftershock_org'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   '...',
#   'http',
#   '//t.co/yvvpznzmxg',
#   'news'],
#  ['strict',
#   'liability',
#   'context',
#   'airplane',
#   'accident',
#   'pilot',
#   'error',
#   'common',
#   'component',
#   'aviation',
#   'cr',
#   '...',
#   'http',
#   '//t.co/6cz3bohrd4'],
#  ['crobscarla',
#   'lifetime',
#   'odds',
#   'dying',
#   'airplane',
#   'accident',
#   '1',
#   '8015'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wedn',
#   '...',
#   'http',
#   '//t.co/bkpfpogysi'],
#  ['alexalltimelow',
#   'awwww',
#   "'re",
#   'airplane',
#   'accident',
#   "'re",
#   'gon',
#   'na',
#   'die',
#   'cuties',
#   'good',
#   'job'],
#  ['family',
#   'members',
#   'osama',
#   'bin',
#   'laden',
#   'died',
#   'airplane',
#   'accident',
#   'ironic',
#   'mhmmm',
#   'gov',
#   'shit',
#   'suspect'],
#  ['man',
#   'goes',
#   'airplane',
#   'engine',
#   'accident',
#   'http',
#   '//t.co/tyjxrfd3st',
#   'via',
#   'youtube'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'wings',
#   'airplane',
#   '29-07-2015',
#   'http',
#   '//t.co/i7kztevb2v'],
#  ['cessna',
#   'airplane',
#   'accident',
#   'ocampo',
#   'coahuila',
#   'mexico',
#   'july',
#   '29',
#   '2015',
#   'killed',
#   'four',
#   'men',
#   'including',
#   'state',
#   'coahuila',
#   'government',
#   'official'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'wings',
#   'airplane',
#   '29-07-2015',
#   'watchthevideo',
#   'http',
#   '//t.co/p64xrvgjik'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'http',
#   '//t.co/lsmx2vwr3j',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday\x89û_'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday',
#   'began',
#   'examining',
#   '...'],
#  ['kca',
#   'votejkt48id',
#   'mbataweel',
#   'rip',
#   'binladen',
#   'family',
#   'members',
#   'killed',
#   'airplane',
#   "'s",
#   'accident'],
#  ['almost',
#   'sent',
#   'coworker',
#   'nudes',
#   'accident',
#   'thank',
#   'god',
#   'airplane',
#   'mode'],
#  ['mickinyman',
#   'theatlantic',
#   'might',
#   'killed',
#   'airplane',
#   'accident',
#   'night',
#   'car',
#   'wreck',
#   'politics',
#   "'s",
#   'best'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   '...',
#   'http',
#   '//t.co/tagzbcxfj0',
#   'mlb'],
#  ['unbelievably',
#   'insane',
#   'man',
#   'airport',
#   'airplane',
#   'aircraft',
#   'aeroplane',
#   'runway',
#   'accident',
#   'freaky\x89û_',
#   'https',
#   '//t.co/cezhq7czll'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'wings',
#   'airplaneåê',
#   '29-07-2015',
#   'http',
#   '//t.co/wq3wjsgphl'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'wings',
#   'airplane',
#   '29-07-2015',
#   'http',
#   '//t.co/tfcdronra6'],
#  ['usama',
#   'bin',
#   'ladins',
#   'family',
#   'dead',
#   'airplane',
#   'crash',
#   'naturally',
#   'accident'],
#  ['pilot',
#   'dies',
#   'plane',
#   'crash',
#   'car',
#   'festival',
#   'https',
#   '//t.co/kq9ae6ap2b',
#   'via',
#   'youtube',
#   'crash',
#   'aircraft',
#   'airplane',
#   'pilot',
#   'death',
#   'accident',
#   'carfest'],
#  ['strict',
#   'liability',
#   'context',
#   'airplane',
#   'accident',
#   'http',
#   '//t.co/gibyqhhkpk'],
#  ['dtn',
#   'brazil',
#   'experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'exp',
#   '...',
#   'http',
#   '//t.co/m9ig3wq8lq'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wedn',
#   '...',
#   'http',
#   '//t.co/v4smaeslk5'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'wings',
#   '\x89ûïairplane\x89û\x9d',
#   '29-07-2015.',
#   'wtf',
#   'can\x89ûªt',
#   'believe',
#   'eyes',
#   '\x89ûò',
#   '...',
#   'http',
#   '//t.co/6ffylajwps'],
#  ['nicole',
#   'fletcher',
#   'one',
#   'victim',
#   'crashed',
#   'airplane',
#   'times',
#   'ago',
#   'accident',
#   'left',
#   'little',
#   'bit',
#   'trauma',
#   'although',
#   "'s"],
#  ['omg',
#   'horrible',
#   'accident',
#   'man',
#   'died',
#   'wings',
#   'airplane',
#   'http',
#   '//t.co/xdxdprcpns'],
#  ['omg',
#   "n't",
#   'believe',
#   'rip',
#   'bro',
#   'airplane',
#   'accident',
#   'jetengine',
#   'turbojet',
#   'boing',
#   'g90',
#   'http',
#   '//t.co/kxxnszp6nk'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday',
#   'began',
#   'examining',
#   '...'],
#  ['airplane', 'accident'],
#  ['phone', 'looks', 'like', 'car', 'ship', 'airplane', 'accident', 'terrible'],
#  ['statistically',
#   "'m",
#   'risk',
#   'getting',
#   'killed',
#   'cop',
#   'dying',
#   'airplane',
#   'accident'],
#  ['airplane',
#   'crashes',
#   'house',
#   'colombia',
#   '12',
#   'people',
#   'die',
#   'accident',
#   'https',
#   '//t.co/zhjlflbhzl'],
#  ['shooting', 'airplane', 'accident', 'https', '//t.co/iecc1jdoub'],
#  ['could',
#   'drone',
#   'cause',
#   'airplane',
#   'accident',
#   'pilots',
#   'worried',
#   'use',
#   'drones',
#   'esp',
#   'close',
#   'vicinity',
#   'airports',
#   'http',
#   '//t.co/kz35rgngjf'],
#  ['early',
#   'wake',
#   'call',
#   'sister',
#   'begging',
#   'come',
#   'amp',
#   'ride',
#   'w/her',
#   'ambulance',
#   'hospital',
#   'rodkiai'],
#  ['http',
#   '//t.co/ay6zzcupnz',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/sc9dns41mc'],
#  ['two',
#   'air',
#   'ambulances',
#   'scene',
#   'serious',
#   'crash',
#   'two',
#   'cars',
#   'lorry',
#   '...',
#   'http',
#   '//t.co/9pfeaqeski',
#   'http',
#   '//t.co/fntg70rnkx',
#   'emsne\x89û_'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'reuters',
#   'http',
#   '//t.co/mdnugvubwn',
#   'yugvani'],
#  ['leading',
#   'emergency',
#   'services',
#   'boss',
#   'welcomes',
#   'new',
#   'ambulance',
#   'charity',
#   'http',
#   '//t.co/mj2jq2psv6'],
#  ['anyone',
#   'travelling',
#   'aberystwyth-shrewsbury',
#   'right',
#   "'s",
#   'incident',
#   'services',
#   'halt',
#   'outside',
#   'shrews',
#   'ambulance',
#   'scene'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/xum8ylcb4q'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   '14',
#   'lez',
#   'compliant',
#   'ebay',
#   'http',
#   '//t.co/4evttqpeia'],
#  ['new',
#   'nanotech',
#   'device',
#   'able',
#   'target',
#   'destroy',
#   'blood',
#   'clots',
#   'http',
#   '//t.co/hfy5v3slbb'],
#  ['20skyhawkmm20',
#   'traplord_29',
#   'fredosantana300',
#   'lilreese300',
#   'hella',
#   'crazy',
#   '3',
#   'fights',
#   'ambulance',
#   'couple',
#   'mosh',
#   'pits'],
#  ['get', 'run', 'ambulance', 'lucky', 'justsaying', 'randomthought'],
#  ['news',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/bfes5twbzt',
#   'til_now',
#   'dna'],
#  ['http',
#   '//t.co/7xglah10zl',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/thmblaatzp'],
#  ['tanslash', 'waiting', 'ambulance'],
#  ['fouseytube',
#   'ok',
#   'need',
#   'ambulance',
#   'hahahah',
#   'good',
#   'http',
#   '//t.co/zsberqnn9n'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   '14',
#   'lez',
#   'compliant',
#   'ebay',
#   'http',
#   '//t.co/q8ivrzojzv'],
#  ['pakistan',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'kills',
#   'nine',
#   'http',
#   '//t.co/8e7ry8ebmf'],
#  ['thenissonian',
#   'rejectdcartoons',
#   'nissan',
#   'ok',
#   'need',
#   'medical',
#   'assistance',
#   'call',
#   'ambulance',
#   'need'],
#  ['ems1',
#   'ny',
#   'emts',
#   'petition',
#   '17',
#   'per',
#   'hour',
#   '\x89û÷minimum',
#   'wage\x89ûª',
#   'http',
#   '//t.co/4oa6swlxmr',
#   'ems',
#   'paramedics',
#   'ambulance'],
#  ['http',
#   '//t.co/fcqmkffflw',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/vayaymbngu'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/3brme6sn4t'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   '14',
#   'lez',
#   'compliant',
#   'ebay',
#   'http',
#   '//t.co/ujrx9kgawp'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   '14',
#   'lez',
#   'compliant',
#   'ebay',
#   'http',
#   '//t.co/kp2lf4aute'],
#  ['kiwi_karyn',
#   'check',
#   "'s",
#   'parking',
#   'lot',
#   'said',
#   'last',
#   'year',
#   'ambulance',
#   'st',
#   'johns',
#   'http',
#   '//t.co/hpvodud7ip'],
#  ["n't", 'know', 'way', 'ambulance', 'coming', 'lt', 'lt'],
#  ['reuters',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/shzpyiqok5'],
#  ['http',
#   '//t.co/pwwpum6rbj',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/yspon4d6qo'],
#  ['ambulance', 'right', 'outside', 'work'],
#  ['\x89ûï',
#   'leoblakecarter',
#   'dog',
#   'thinks',
#   "'s",
#   'ambulance',
#   'http',
#   '//t.co/mg1lpgr0rm\x89û\x9d',
#   'natasha_rideout'],
#  ['happening',
#   'hatzolah',
#   'ems',
#   'ambulance',
#   'responding',
#   'dual',
#   'sirens',
#   'and\x89û_',
#   'https',
#   '//t.co/sek6mq6njf'],
#  ['http',
#   '//t.co/fuerk0gwui',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/mv7ggglmvc'],
#  ['http',
#   '//t.co/x5yeuylt1x',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/2ugrmd1z1n'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/th9ywbbeet',
#   'worldnews'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/x2qsjod40u',
#   'worldnews'],
#  ["'s", 'police', 'ambulance', 'number', 'lesotho', 'body', 'know'],
#  ['medic914',
#   'aace_org',
#   'surprised',
#   'still',
#   'standardised',
#   'clinical',
#   'practice',
#   'across',
#   '11',
#   'nhs',
#   'ambulance',
#   'trust'],
#  ['http',
#   '//t.co/j8tyt1xrrk',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'http',
#   '//t.co/9d4nazoi94'],
#  ['people', 'try', 'j-walk', 'ambulance', 'passing', '...', 'hate'],
#  ['episode',
#   'trunks',
#   'annihilated',
#   'freiza',
#   'cleanest',
#   'shit',
#   'ever',
#   'showed',
#   'nigga',
#   'mercy'],
#  ['shall',
#   'annihilated',
#   'petebests',
#   'dessicated',
#   'laid',
#   'bare',
#   'shall',
#   'kneel'],
#  ['uribe', 'annihilated', 'baseball', 'mets'],
#  ['marksmaponyane',
#   'hey',
#   'sundowns',
#   'annihilated',
#   'previous',
#   'meeting',
#   'celtic.indeed',
#   'improvement'],
#  ['volfan326',
#   'tneazzy',
#   'mizzou',
#   'annihilated',
#   'florida',
#   'past',
#   '2',
#   'seasons',
#   'even',
#   'ended',
#   'muschamp',
#   "'s",
#   'career',
#   'ca',
#   "n't",
#   'compete',
#   'bama'],
#  ['annihilated', 'abs', 'http', '//t.co/1xpw292tje'],
#  ['annihilated',
#   'status',
#   'education',
#   'mba',
#   'behalf',
#   'easy',
#   'street',
#   'careen',
#   'eovm',
#   'http',
#   '//t.co/e0pi0c54ff'],
#  ['luka', 'die', 'everything', 'annihilated', 'alois', 'trancy'],
#  ['acarewornheart',
#   'good',
#   'un',
#   'fella',
#   'sorry',
#   'wo',
#   "n't",
#   'get',
#   'annihilated'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'http',
#   '//t.co/thrhkhogcuåê',
#   'http',
#   '//t.co/tzszmf2qxe',
#   'via',
#   'viralspell'],
#  ['must', 'annihilated'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'http',
#   '//t.co/c0nkgp6w03åê',
#   'http',
#   '//t.co/imwmfdjssn',
#   'via',
#   'viralspell'],
#  ['boom',
#   'country',
#   'entirely',
#   'annihilated',
#   'h\x89û_',
#   '\x89ûó',
#   'britain',
#   'https',
#   '//t.co/irfcn71szv'],
#  ['amirkingkhan',
#   'would',
#   'annihilated',
#   'might',
#   'well',
#   'thank',
#   'floydmayweather'],
#  ['one',
#   'thing',
#   'sure-god',
#   'promised',
#   'israel',
#   'annihilated',
#   '...',
#   'horror',
#   'iran',
#   'w/nukes',
#   'https',
#   '//t.co/xn09mx6sxy'],
#  ['violentfeminazi',
#   'guess',
#   "'s",
#   'ok',
#   'armenians',
#   'since',
#   "'ve",
#   'spent',
#   'history',
#   'getting',
#   'annihilated'],
#  ['70',
#   'years',
#   'since',
#   'annihilated',
#   '100000',
#   'people',
#   'instantly',
#   'became',
#   'aware',
#   'ability',
#   'annihilate',
#   'whole',
#   'humanity'],
#  ['day',
#   '1',
#   'tryouts',
#   'went',
#   'good',
#   'minus',
#   'fact',
#   'stopped',
#   'quickly',
#   'get',
#   'short',
#   'ball',
#   'annihilated',
#   'toenail',
#   'injury',
#   'even'],
#  ['1960s',
#   'oryx',
#   'symbol',
#   'arabian',
#   'peninsula',
#   'annihilated',
#   'hunters',
#   'http',
#   '//t.co/yangeqbuqw',
#   'http',
#   '//t.co/jq2eh5kglt'],
#  ['luka', "'they", 'die', 'everything', 'annihilated', 'alois', 'trancy'],
#  ['ready', 'get', 'annihilated', 'bucs', 'game'],
#  ['philipduncan',
#   'breakfastone',
#   'people',
#   "'annihilated",
#   'last',
#   'nights',
#   'weather',
#   '...',
#   'really',
#   'philip',
#   'thought',
#   'would',
#   'forecast',
#   '...'],
#  ['domain',
#   'sophistication',
#   'annihilated',
#   'closely',
#   'up-to-the-minute',
#   'feat',
#   'zrnf'],
#  ['stormbeard',
#   'steel_lord',
#   'seen',
#   'judas',
#   'priest',
#   '2005',
#   'rob',
#   'came',
#   'back',
#   'scorpions',
#   'support',
#   'fucking',
#   'annihilated',
#   'place',
#   'astonishing',
#   'gig'],
#  ['officially',
#   'skipping',
#   'fantasticfour/',
#   'fant4stic/whatever',
#   'hashtag',
#   "'s",
#   'getting',
#   'annihilated',
#   'reviews',
#   'bummer'],
#  ['tomcatarts',
#   'thus',
#   'explaining',
#   'annihilated',
#   'case',
#   'survivor',
#   'evolved',
#   'became',
#   'godlike'],
#  ['completely', 'annihilated', 'cech', 'paul', 'keegan', 'time', 'alive'],
#  ['tomcatarts',
#   "'who",
#   'annihilated',
#   'legion',
#   'survivors',
#   'imperfect',
#   'hybrid',
#   'project',
#   'quickly',
#   'formed',
#   'new',
#   'secret',
#   'cell'],
#  ['sirbrandonknt',
#   'exactly',
#   "'s",
#   'lesnar/cena',
#   'match',
#   'summerslam',
#   'last',
#   'year',
#   'great',
#   'brock',
#   'annihilated',
#   'guy',
#   "'s"],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'http',
#   '//t.co/f1bakpnyn6åê',
#   'http',
#   '//t.co/lzxwoaye4x',
#   'via',
#   'viralspell'],
#  ['annihilated',
#   'damascus',
#   'syrian',
#   'army',
#   'grinds',
#   '\x89û÷alloosh',
#   'gang',
#   'manure',
#   'pile',
#   'http',
#   '//t.co/7rakhp3bwm'],
#  ['thatdes',
#   'ok',
#   "n't",
#   'completely',
#   'forthright',
#   'may',
#   'also',
#   'food',
#   'coma',
#   'bc',
#   'kebab/tahini/pickles',
#   'also',
#   'annihilated',
#   'w/fries'],
#  ['fun',
#   'filled',
#   'happy-hour',
#   'simmons',
#   'bar',
#   'camden',
#   'handsome',
#   'one',
#   'got',
#   'annihilated',
#   'apart',
#   'game',
#   'http',
#   '//t.co/4jno677zkv'],
#  ['juanny', 'beisbol', 'sr.', 'annihilated', 'ball', 'lgm'],
#  ['rvfriedmann',
#   'hell',
#   'fraction',
#   'belief',
#   'total',
#   'annihilation',
#   'destruction',
#   'usa',
#   'lodisilverado',
#   'ritzy_jewels'],
#  ['potus',
#   'maybe',
#   'call',
#   'israel',
#   'tell',
#   "'re",
#   'sorry',
#   'pres',
#   'sold',
#   'river',
#   'annihilation'],
#  ['evildead', 'annihilation', 'civilization', 'http', '//t.co/spfke5kqu4'],
#  ['u.s',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   '...',
#   'http',
#   '//t.co/6lojoorouk',
#   'via',
#   'change'],
#  ['annihilating', 'quarterstaff', 'annihilation'],
#  ['world',
#   'annihilation',
#   'vs',
#   'self',
#   'transformation',
#   'http',
#   '//t.co/pyehwodwun',
#   'aliens',
#   'attack',
#   'exterminate',
#   'humans',
#   'http',
#   '//t.co/pb2n77nskz'],
#  ['starmade',
#   'stardate',
#   '3',
#   'planetary',
#   'annihilation',
#   'http',
#   '//t.co/i2hhviumtm',
#   'via',
#   'youtube'],
#  ['u.s',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   '...',
#   'https',
#   '//t.co/m8mvdspjp7',
#   'via',
#   'change'],
#  ['u.s',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   '...',
#   'https',
#   '//t.co/sw1sbua3mn',
#   'via',
#   'change'],
#  ['kimkardashian',
#   'please',
#   'sign',
#   'share',
#   'petition',
#   'save',
#   'wild',
#   'horses',
#   'arizona',
#   'http',
#   '//t.co/3tssxphufe'],
#  ['u.s',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   '...',
#   'http',
#   '//t.co/kpqk0c4g0m',
#   'via',
#   'change'],
#  ['theellenshow',
#   'please',
#   'check',
#   'salt',
#   'river',
#   'horses',
#   'help',
#   'stop',
#   'annihilation',
#   'happen',
#   'without',
#   '54000',
#   'signatures.change',
#   '.org',
#   'thx'],
#  ['souls',
#   'punished',
#   'withåêannihilation',
#   'http',
#   '//t.co/c1qxjweqqu',
#   'http',
#   '//t.co/zhp0sowxry'],
#  ['calfreedommom',
#   'steph93065',
#   'mention',
#   'major',
#   'contributor',
#   'annihilation',
#   'israel'],
#  ['willienelson',
#   'need',
#   'help',
#   'horses',
#   'die',
#   'please',
#   'rt',
#   'amp',
#   'sign',
#   'petition',
#   'take',
#   'stand',
#   'amp',
#   'voice',
#   'gilbert23',
#   'https',
#   '//t.co/e8dl1lncvu'],
#  ['reject',
#   'laws',
#   'misguided',
#   'false',
#   'prophets',
#   'imprison',
#   'nations',
#   'fueling',
#   'self',
#   'annihilation'],
#  ['u.s',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   '...',
#   'https',
#   '//t.co/matijwkzbh',
#   'via',
#   'change'],
#  ['annihilation',
#   'jeb',
#   'christie',
#   'amp',
#   'kasich',
#   'less',
#   '24',
#   'hours',
#   'away',
#   '..',
#   'please',
#   'god',
#   'allow',
#   'least',
#   'one',
#   'full',
#   'day',
#   '...'],
#  ['barbi_twins',
#   'need',
#   'help-horses',
#   'die',
#   'please',
#   'rt',
#   'amp',
#   'sign',
#   'petition',
#   'take',
#   'stand',
#   'amp',
#   'voice',
#   'gilbert23',
#   'https',
#   '//t.co/e8dl1lncvu'],
#  ['whippenz',
#   'need',
#   'help',
#   'horses',
#   'die',
#   'please',
#   'rt',
#   'amp',
#   'sign',
#   'petition',
#   'take',
#   'stand',
#   'amp',
#   'voice',
#   'gilbert23',
#   'https',
#   '//t.co/e8dl1lncvu'],
#  ['hey',
#   'az',
#   'sign',
#   'petition',
#   'save',
#   'wildhorses',
#   'tantonationalforest',
#   'rollingstones',
#   'sing-a-long',
#   'order',
#   'http',
#   '//t.co/wm5l8pj2iy'],
#  ['stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horses',
#   'http',
#   '//t.co/wvobvvtxkg',
#   'via',
#   'change'],
#  ['sonofbaldwin',
#   "'s",
#   'current',
#   'nova',
#   'bookslast',
#   'checked',
#   '..',
#   'tied',
#   'books',
#   '2011',
#   'rider',
#   'died',
#   'annihilation'],
#  ['u.s',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   '...',
#   'https',
#   '//t.co/x2wn7o2a3w',
#   'via',
#   'change'],
#  ['please',
#   'sign',
#   'amp',
#   'rt',
#   'save',
#   'saltriverwildhorses',
#   'http',
#   '//t.co/ikuayuseqt',
#   'http',
#   '//t.co/bqbhuyfme9'],
#  ['thanks',
#   'count',
#   'dante',
#   'join',
#   'us',
#   'following',
#   'annihilation',
#   'zone',
#   'johnny'],
#  ['world',
#   'annihilation',
#   'vs',
#   'self',
#   'transformation',
#   'http',
#   '//t.co/pyehwodwun',
#   'aliens',
#   'attack',
#   'exterminate',
#   'humans',
#   'http',
#   '//t.co/8jxql8cv8z'],
#  ['u.s',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   '...',
#   'https',
#   '//t.co/0fekgyby5f',
#   'via',
#   'change'],
#  ['u.s',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   '...',
#   'http',
#   '//t.co/sb5r7shccj',
#   'via',
#   'change'],
#  ["'m", 'gon', 'na', 'fight', 'taylor', 'soon', 'get'],
#  ['ohh',
#   'fukurodani',
#   "n't",
#   'survive',
#   'apocalypse',
#   'bokuto',
#   'feels',
#   'horrible',
#   'poor',
#   'boy',
#   'ppor',
#   'child'],
#  ['another', 'jocelyn', 'birthday', 'apocalypse'],
#  ['rt',
#   'janenelson097',
#   'rt',
#   'stephenscifi',
#   'adaptation',
#   'watch',
#   'charlie',
#   'human',
#   "'s",
#   'apocalypse',
#   'optioned',
#   'film',
#   'sciencefiction',
#   '\x89û_'],
#  ['apocalypse', 'please'],
#  ['another',
#   'hour',
#   "'s",
#   'august',
#   '05',
#   '2015',
#   '08:02pm',
#   "'s",
#   'red',
#   'rover',
#   'zombie',
#   'apocalypse',
#   '2014',
#   'http',
#   '//t.co/cf9e6tu3g7',
#   'internetradio',
#   'collegeradi\x89û_'],
#  ['honeybunzgem',
#   'primalkitchen',
#   'feel',
#   'like',
#   'pull-up',
#   'one',
#   'stages',
#   'apocalypse'],
#  ["'s",
#   'kinda',
#   'hot',
#   'played',
#   'radio',
#   'today',
#   "'s",
#   'next',
#   'disease',
#   'apocalypse',
#   'started',
#   'everyone',
#   'careful'],
#  ["'s", 'apocalypse', 'lol', 'gf', 'm8'],
#  ['know',
#   "'s",
#   'question',
#   'interpretation',
#   'sign',
#   'apocalypse',
#   'called',
#   'https',
#   '//t.co/my8q1uwijn'],
#  ['julie', 'r', 'apocalypse', 'version', 'romeo', 'juliet', 'warmbodies'],
#  ['apocalypse', 'upon', 'us'],
#  ['rt',
#   'fittscott',
#   'minecraft-',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   '2.0',
#   'amp',
#   'mod',
#   'showcase',
#   'popularmmos',
#   'http',
#   '//t.co/mul1j9aeux',
#   'vi\x89û_'],
#  ['begins', '..', 'day', 'one', 'snow', 'apocalypse'],
#  ['rt',
#   'our_mother_mary',
#   'short',
#   'reading',
#   'apocalypse',
#   '21:1023',
#   'spirit',
#   'angel',
#   'took',
#   'top',
#   'enormous',
#   'high',
#   'mountain',
#   '...',
#   '\x89û_'],
#  ['candylit',
#   'imagine',
#   'sarumi',
#   'zombie',
#   'apocalypse',
#   'fighting',
#   'back',
#   'back',
#   'heart',
#   'heart',
#   'conversations',
#   '...',
#   'http',
#   '//t.co/xizkjfff29'],
#  ['rt',
#   'zonewolf123',
#   'liked',
#   'youtube',
#   'video',
#   'http',
#   '//t.co/u66kyg11zd',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   '2.0',
#   'amp',
#   'mo\x89û_'],
#  ["'s", 'planet', "'s", 'lone', 'audience', 'apocalypse'],
#  ['dad',
#   'bought',
#   'dvd',
#   'looks',
#   'like',
#   'science',
#   'doc',
#   'front',
#   'read',
#   'back',
#   "'s",
#   'actually',
#   'impending',
#   'biblical',
#   'apocalypse'],
#  ['alexandrapullin', 'indeed', 'apocalypse', 'comes', 'week', 'know', "'ll"],
#  ['go',
#   'look',
#   'grizzly',
#   'peak',
#   'right',
#   '...',
#   'looks',
#   'like',
#   'beginning',
#   'dystopian',
#   'apocalypse',
#   'movie'],
#  ['niece', 'asked', "'would", 'scared', 'apocalypse'],
#  ["'s",
#   'storm',
#   'cairo',
#   'latest',
#   'x-men',
#   'apocalypse',
#   'set',
#   'photo',
#   'https',
#   '//t.co/fs012trudg',
#   'via',
#   'yahootv'],
#  ['minecraft-',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   '2.0',
#   'amp',
#   'mod',
#   'showcase',
#   'popularmmos',
#   'http',
#   '//t.co/tngye2fklv',
#   'via',
#   'youtube'],
#  ['shot',
#   'heart',
#   'xv',
#   'going',
#   'totally',
#   'give',
#   'love',
#   'bad',
#   'name',
#   'heart',
#   'pierc',
#   'http',
#   '//t.co/xpfmr368uf',
#   'http',
#   '//t.co/ejdhvlkxaf'],
#  ['rt',
#   'geek_apocalypse',
#   '4pm',
#   'gmt',
#   'hesse',
#   'plays',
#   'dark',
#   'souls',
#   '2',
#   'day',
#   '9',
#   'http',
#   '//t.co/tngpshnl87',
#   'http',
#   '//t.co/imzlnzltf5',
#   'etcpb'],
#  ['know', 'go', 'zombies', 'take', 'http', '//t.co/huthxlkyxy'],
#  ['latest',
#   'bryansinger',
#   'reveals',
#   'storm',
#   'queen',
#   'apocalypse',
#   'rupaul',
#   'alexshipppp',
#   'http',
#   '//t.co/oqw8jx6rts'],
#  ['shadow', 'boxing', 'apocalypse'],
#  ['short',
#   'reading',
#   'apocalypse',
#   '21:1023',
#   'spirit',
#   'angel',
#   'took',
#   'top',
#   'enormous',
#   'high',
#   'mountain',
#   '...',
#   'http',
#   '//t.co/v8aftd9zez'],
#  ['enjoyed',
#   'live-action',
#   'attack',
#   'titan',
#   'every',
#   'time',
#   'see',
#   'posters',
#   "'m",
#   'reminded',
#   'freshly',
#   'clean',
#   'coiffed',
#   'everyone',
#   'apocalypse'],
#  ['liked',
#   'youtube',
#   'video',
#   'http',
#   '//t.co/ki1ykrs9fi',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   '2.0',
#   'amp',
#   'mod',
#   'showcase'],
#  ['pbban',
#   'temporary:300',
#   'avysss',
#   "'armageddon",
#   'kill',
#   'flags',
#   'fast',
#   'xp',
#   'reason'],
#  ['pbban',
#   'temporary:300',
#   'russaky89',
#   "'armageddon",
#   'kill',
#   'flags',
#   'fast',
#   'xp',
#   'reason'],
#  ['official',
#   'vid',
#   'doublecups',
#   'gt',
#   'gt',
#   'https',
#   '//t.co/lfkmtzaekk',
#   'gt',
#   'gt',
#   'trubgme',
#   'prod',
#   'thisizbwright',
#   'gt',
#   'gt',
#   'armageddon'],
#  ['ouvindo', 'peace', 'love', 'amp', 'armageddon'],
#  ['best',
#   'movie',
#   "'ve",
#   'ever',
#   'seen',
#   'armageddon',
#   'http',
#   '//t.co/qouxigdtbz'],
#  ['bed', 'time', "n't", 'wake', 'unless', 'revolution', 'armageddon', 'start'],
#  ['red',
#   'faction',
#   'armageddon',
#   'microsoft',
#   'xbox',
#   '360',
#   '2011',
#   'full',
#   'read',
#   'ebay',
#   'http',
#   '//t.co/ypbvs1ijya',
#   'http',
#   '//t.co/9dflv6ynqr'],
#  ['katiekatcubs',
#   'already',
#   'know',
#   'shit',
#   'goes',
#   'world',
#   'series',
#   'armageddon'],
#  ['rt',
#   'ophiuchus2613',
#   'love',
#   'truelove',
#   'romance',
#   'lith',
#   'voodoo',
#   'seduction',
#   'astrology',
#   'rtrrt',
#   'lotz',
#   '9-11',
#   'apocalypse',
#   'armageddon',
#   '1008pla\x89û_'],
#  ['//im',
#   'gon',
#   'na',
#   'beat',
#   'armageddon',
#   'hsu',
#   'hao',
#   'got',
#   'flawless',
#   'first',
#   'try'],
#  ['enews',
#   'ben',
#   'affleck',
#   '......',
#   'know',
#   "'s",
#   'wife/kids',
#   'girls',
#   'ca',
#   "n't",
#   'help',
#   "'ve",
#   'loved',
#   'since',
#   'armageddon',
#   'eonlinechat'],
#  ["'if",
#   "'d",
#   'long',
#   'coat',
#   'hand',
#   "'d",
#   'worn',
#   'certainty',
#   'armageddon',
#   'bears',
#   'sense',
#   'occasion'],
#  ['phone',
#   'spying',
#   'hidden',
#   'back',
#   'door',
#   'nsa',
#   'data',
#   'mining',
#   'software',
#   'financial',
#   'armageddon',
#   'blog',
#   'http',
#   '//t.co/qycw5jjaj1'],
#  ['pbban',
#   'temporary:300',
#   'hyider_ghost2',
#   "'armageddon",
#   'kill',
#   'flags',
#   'fast',
#   'xp',
#   'reason'],
#  ['rt',
#   'rtrrtcoach',
#   'love',
#   'truelove',
#   'romance',
#   'lith',
#   'voodoo',
#   'seduction',
#   'astrology',
#   'rtrrt',
#   'lotz',
#   '9-11',
#   'apocalypse',
#   'armageddon',
#   '1008planet\x89û_'],
#  ['pbban',
#   'temporary:300',
#   'fighterdena',
#   "'armageddon",
#   'kill',
#   'flags',
#   'fast',
#   'xp',
#   'reason'],
#  ['photo',
#   'sketch',
#   'based',
#   'taste',
#   'armageddon',
#   'episode',
#   'startrek',
#   'tos',
#   'http',
#   '//t.co/a2e6dcsk88'],
#  ['armageddon', 'https', '//t.co/ucsudk3q1d'],
#  ['aberdeenfc',
#   'aberdeenfanpage',
#   'good',
#   'luck',
#   'tomorrow',
#   'night',
#   'get',
#   'coefficient',
#   'points',
#   'plz',
#   'armageddon'],
#  ['paddytomlinson1', 'armageddon'],
#  ['rohnertparkdps',
#   "'re",
#   'another',
#   'one',
#   'history',
#   'books',
#   'thank',
#   'justice',
#   'department',
#   'way',
#   "n't",
#   'paid',
#   'income',
#   'tax',
#   '20yrs'],
#  ['vladimir',
#   'putin',
#   'issues',
#   'major',
#   'warning',
#   'late',
#   'escape',
#   'armageddon',
#   'http',
#   '//t.co/gbxafy1m1c'],
#  ['god',
#   "'s",
#   'kingdom',
#   'heavenly',
#   "gov't",
#   'rule',
#   'people',
#   'earth',
#   'armageddon',
#   'http',
#   '//t.co/8hgcbxukz0',
#   'http',
#   '//t.co/4kopkcyvtt'],
#  ['l',
#   'b',
#   'entertainment',
#   'lot',
#   '8',
#   'brucewillis',
#   'movies',
#   'dvd',
#   'die',
#   'hard',
#   '1',
#   '2',
#   '12',
#   'monkeys',
#   'armageddon',
#   'sixth',
#   'ebay',
#   'auction',
#   'http',
#   '//t.co/cxdjapzxmp'],
#  ['let\x89ûªs',
#   'talk',
#   'goof',
#   'guild',
#   'saunders',
#   'come',
#   'right',
#   'stage',
#   'https',
#   '//t.co/hkbxxvd9iw'],
#  ['karnythia',
#   'niece',
#   'gaining',
#   'ability',
#   'stand',
#   "'m",
#   'getting',
#   'prepared',
#   'toddler',
#   'apocalypse',
#   'armageddon'],
#  ['check',
#   'preppers',
#   'doomsday',
#   'must',
#   'library',
#   'collection',
#   'cd',
#   'shtf',
#   'preppertalk',
#   'survival',
#   '2a',
#   'prepper',
#   'http',
#   '//t.co/vpqtgeqlma',
#   'via',
#   'ebay'],
#  ['erker',
#   'eep',
#   'thought',
#   'yesterday',
#   'saw',
#   'hella',
#   'scary',
#   'hail',
#   'armageddon'],
#  ['ahamedis',
#   'think',
#   'messiah',
#   'already',
#   'come',
#   '125',
#   'years',
#   'ago',
#   'armageddon',
#   'dajaal',
#   'gog',
#   'amp',
#   'magog'],
#  ['sadly',
#   'windows',
#   '10',
#   'reveals',
#   'microsoft',
#   "'s",
#   'ethics',
#   'armageddon',
#   'http',
#   '//t.co/stftjcrjea'],
#  ['armageddon', 'averted', 'el', 'patron', 'ultimalucha'],
#  ['samihonkonen',
#   'time',
#   '23',
#   'hours',
#   'latest',
#   'series',
#   'ww1',
#   'blueprint',
#   'armageddon',
#   'extremely',
#   'impressive'],
#  ['european', 'fitba', 'till', 'christmas', 'armageddon'],
#  ['christians',
#   'united',
#   'israel',
#   'cufi',
#   'jews',
#   'convert',
#   'soon',
#   'die',
#   'armageddon',
#   'https',
#   '//t.co/4arwwrzpsr',
#   'us',
#   'http',
#   '//t.co/mkjq9yfmp8'],
#  ['official',
#   'vid',
#   'gt',
#   'doublecups',
#   'gt',
#   'gt',
#   'https',
#   '//t.co/lfkmtzaekk',
#   'gt',
#   'gt',
#   'trubgme',
#   'prod',
#   'thisizbwright',
#   'gt',
#   'gt',
#   'armageddon'],
#  ['tomorrow', 'day', 'start', 'armageddon', 'preseasonworkouts'],
#  ['lee',
#   'comedy',
#   '\x89ûï',
#   'leejasper',
#   'working',
#   'class',
#   'tories',
#   'prepare',
#   'armageddon',
#   'interestraterise\x89û\x9d'],
#  ['9',
#   'charts',
#   'prove',
#   'financial',
#   'crisis',
#   'part',
#   '2',
#   'begun',
#   'financial',
#   'armageddon',
#   'economic',
#   'collapse',
#   'blog',
#   'tracks',
#   'tren',
#   '...',
#   'http',
#   '//t.co/vhcxtvcinr'],
#  ['paul',
#   'craig',
#   'roberts',
#   '\x89ûò',
#   'vladimir',
#   'putin',
#   'issues',
#   'major',
#   'warning',
#   'late',
#   'escape',
#   'http',
#   '//t.co/nvfkzv5fex',
#   'brics',
#   'roberts',
#   'russia'],
#  ['rohnertparkdps',
#   "'re",
#   'stage',
#   'right',
#   'lights',
#   "n't",
#   'funny',
#   'get',
#   'goofballs',
#   'staff',
#   'pd'],
#  ['official',
#   'vid',
#   'thereal',
#   'gt',
#   'gt',
#   'gt',
#   'https',
#   '//t.co/4i0rjc9rqu',
#   'gt',
#   'gt',
#   'gt',
#   'trubgme',
#   'gt',
#   'gt',
#   'gt',
#   'armageddon',
#   'comin',
#   'soon'],
#  ['well',
#   'done',
#   'celtic',
#   'fingers',
#   'crossed',
#   'aberdeen',
#   'tomorrow',
#   'night',
#   'armageddon',
#   'eh',
#   '....'],
#  ['beyonce',
#   'pick',
#   'http',
#   '//t.co/nnmqlz91o9',
#   'fan',
#   'army',
#   'beyhive',
#   'http',
#   '//t.co/o91f3cyy0r',
#   '77'],
#  ['one',
#   'direction',
#   'pick',
#   'http',
#   '//t.co/q2eblokeve',
#   'fan',
#   'army',
#   'directioners',
#   'http',
#   '//t.co/encmhz6y34',
#   'x1402'],
#  ['5',
#   'seconds',
#   'summer',
#   'pick',
#   'http',
#   '//t.co/j6wseptxga',
#   'fan',
#   'army',
#   '5sosfam',
#   'http',
#   '//t.co/qwgiwc9w7z'],
#  ['22.beyonce',
#   'pick',
#   'http',
#   '//t.co/thoyhrhkfj',
#   'fan',
#   'army',
#   'beyhive',
#   'http',
#   '//t.co/wvj39a3bgm'],
#  ['17.beyonce',
#   'pick',
#   'http',
#   '//t.co/thoyhrhkfj',
#   'fan',
#   'army',
#   'beyhive',
#   'http',
#   '//t.co/wvj39a3bgm'],
#  ['one',
#   'direction',
#   'pick',
#   'http',
#   '//t.co/q2eblokeve',
#   'fan',
#   'army',
#   'directioners',
#   'http',
#   '//t.co/encmhz6y34',
#   'x1411'],
#  ['seeing',
#   'army',
#   'whitewalkers',
#   'first',
#   'thing',
#   'slightly',
#   'intrigued',
#   'got',
#   'far'],
#  ['build',
#   'kingdom',
#   'lead',
#   'army',
#   'victory',
#   'https',
#   '//youtu',
#   'start',
#   'g',
#   'friend',
#   'code',
#   'lzktjnox',
#   'http',
#   '//t.co/zz0cewew64'],
#  ['salvation',
#   'army',
#   'hosts',
#   'rally',
#   'reconnect',
#   'fathers',
#   'children',
#   'salvation',
#   'army',
#   'hosting',
#   'back',
#   'school',
#   'rally\x89û_',
#   'http',
#   '//t.co/rdjpor3azg'],
#  ['vote',
#   'directioners',
#   'vs',
#   'queens',
#   '5th',
#   'round',
#   'billboard',
#   'fanarmyfaceoff',
#   'http',
#   '//t.co/kgtxnnbj7y'],
#  ['build',
#   'army',
#   '100',
#   'dogs',
#   'leader',
#   'lion',
#   'dogs',
#   'fight',
#   'like',
#   'lion'],
#  ["'show",
#   'hero',
#   'tv',
#   'review',
#   'http',
#   '//t.co/kaccpk85wf',
#   'http',
#   '//t.co/nnixodhigc'],
#  ['one',
#   'direction',
#   'pick',
#   'http',
#   '//t.co/q2eblokeve',
#   'fan',
#   'army',
#   'directioners',
#   'http',
#   '//t.co/encmhz6y34',
#   'x1392'],
#  ['infantry',
#   'mens',
#   'lume',
#   'dial',
#   'army',
#   'analog',
#   'quartz',
#   'wrist',
#   'watch',
#   'sport',
#   'blue',
#   'nylon',
#   'fabric',
#   'full',
#   'rea\x89û_',
#   'http',
#   '//t.co/hep9k0xghb',
#   'http',
#   '//t.co/80ebvglmra'],
#  ['one',
#   'direction',
#   'pick',
#   'http',
#   '//t.co/q2eblokeve',
#   'fan',
#   'army',
#   'directioners',
#   'http',
#   '//t.co/encmhz6y34',
#   'x1441'],
#  ['victorinox',
#   'swiss',
#   'army',
#   'date',
#   'women',
#   "'s",
#   'rubber',
#   'mop',
#   'watch',
#   '241487',
#   'http',
#   '//t.co/yfy3nkkcoh',
#   'http',
#   '//t.co/knehvvohvk'],
#  ['rt',
#   'drayesha4',
#   'indiakomuntorjawabdo',
#   'indian',
#   'army',
#   'ki\x89û_',
#   'http',
#   '//t.co/wjljq3ya4g'],
#  ['5',
#   'seconds',
#   'summer',
#   'pick',
#   'http',
# ...
#   "'83",
#   "'s",
#   'bloody',
#   'awful',
#   'well',
#   'xxx'],
#  ['nightmare',
#   'elm',
#   'street',
#   'getting',
#   'remade',
#   '...',
#   'http',
#   '//t.co/hvwkjqxxyt'],
#  ['ca',
#   "n't",
#   'bloody',
#   'wait',
#   'sony',
#   'sets',
#   'date',
#   'stephen',
#   'king\x89ûªs',
#   '\x89û÷the',
#   'dark',
#   'tower\x89ûª',
#   'stephenking',
#   'thedarktower',
#   'http',
#   '//t.co/j9lpdrxcde',
#   'bdisgusting'],
#  ['got', 'ta', 'try', 'let', 'go', 'many', 'bloody', 'things', 'smh'],
#  ['tradcatknight',
#   '1',
#   'russia',
#   'may',
#   'played',
#   'reason',
#   'link',
#   'bs',
#   'okanowa',
#   'bloody',
#   'mainline',
#   'invasion',
#   'looked',
#   'like',
#   'bloody'],
#  ['bloody', 'insomnia', 'grrrr', 'insomnia'],
#  ['zhenghxn',
#   'tried',
#   '11',
#   'eyes',
#   'akame',
#   'ga',
#   'kill',
#   'tokyo',
#   'ghoul',
#   'damn',
#   'bloody',
#   'dont',
#   'dare',
#   'watch'],
#  ['fantosex', 'suck', "'s", "'re", 'bloody', 'getting', 'means', 'amends'],
#  ['call',
#   'weekends',
#   'call',
#   'bloody',
#   'mary',
#   'times',
#   'summer',
#   "'s",
#   'full',
#   'new\x89û_',
#   'https',
#   '//t.co/vnni3zzuz6'],
#  ['bloody',
#   'hell',
#   'day',
#   "n't",
#   'even',
#   'really',
#   'done',
#   'anything',
#   'tired',
#   'everything',
#   'thought',
#   'vaca',
#   'would',
#   'help',
#   'much',
#   '=/'],
#  ['damn', 'bloody', 'hot'],
#  ['mrtophypup', "'s", 'bloody', 'sexy', 'drools'],
#  ['know',
#   'say',
#   'side',
#   'effects',
#   'low',
#   'amp',
#   'really',
#   'fast',
#   'son',
#   'product',
#   'acne',
#   'cream',
#   '..',
#   '1',
#   'side',
#   'effects',
#   'bloody',
#   'diarrhea'],
#  ['ronda',
#   'rousey',
#   'would',
#   "'close",
#   'making',
#   'floyd',
#   'mayweather',
#   "'s",
#   'money',
#   '50',
#   'fights',
#   'bloody',
#   'elbow',
#   'http',
#   '//t.co/ijzcytbffo',
#   'boxing'],
#  ["'m",
#   'awful',
#   'painting',
#   '..',
#   'agree',
#   'a3',
#   'landscape',
#   'bloody',
#   'oils',
#   'paints'],
#  ['need',
#   'life',
#   'sin',
#   'girlfriend',
#   'ride',
#   'till',
#   'bloody',
#   'end',
#   'girlfriend'],
#  ['_itsmegss_', 'think', 'well', "'s", 'bloody', 'barking'],
#  ['eh',
#   'hello',
#   'cover',
#   'bloody',
#   'thighs',
#   'bloody',
#   'cleav',
#   '...',
#   '\x89ûó',
#   'eh',
#   'hello',
#   'since',
#   'expose',
#   'cleavage',
#   '...',
#   'http',
#   '//t.co/kv5l4ppxfg'],
#  ['mariasherwood2', 'johnjcampbell', 'mega', 'bloody', 'marvellous'],
#  ['bloody', 'mary', 'sink', 'beet', 'juice', 'http', '//t.co/luigmhma1i'],
#  ['melrises',
#   'gayler1969',
#   'wwwbigbaldhead',
#   'jessienojoke',
#   'melissaross9847',
#   'monty',
#   'python',
#   'date',
#   'bloody',
#   'far',
#   'wants',
#   'go'],
#  ['meet', 'bloody', 'rs5', 'http', '//t.co/rvczmimfvx'],
#  ['friday',
#   'supposed',
#   'happy',
#   'day',
#   "'s",
#   'bloody',
#   'friday',
#   'hah',
#   'zzzz'],
#  ['chxrmingprince',
#   'jones_luna',
#   'bloody',
#   'hope',
#   'said',
#   'folding',
#   'arms',
#   'sitting',
#   'back',
#   'chair'],
#  ['wait',
#   'tell',
#   'college',
#   'friend',
#   'reafs',
#   'bloody',
#   'mary',
#   'drama',
#   'cd'],
#  ['came',
#   'kill',
#   'indians',
#   '...',
#   'fun',
#   'video',
#   'smirking',
#   'remorseless',
#   'pakistani',
#   'killer',
#   'shows',
#   'boasting',
#   'http',
#   '//t.co/fpjlwoxklg'],
#  ["'ve",
#   'watched',
#   'episode',
#   's01e09',
#   'bloody',
#   'monday',
#   'http',
#   '//t.co/vrpthvpymt',
#   'bloodymonday',
#   'tvshowtime',
#   'http',
#   '//t.co/nkkvknbvoz'],
#  ['marlon',
#   'williams',
#   'gt',
#   'elvis',
#   'presley',
#   'gt',
#   'marlon',
#   'williams',
#   'gt',
#   'steel',
#   'panther',
#   'shuffle',
#   'mode',
#   'like',
#   'bloody',
#   'legend'],
#  ['black',
#   'friday',
#   'turns',
#   'bloody',
#   'would',
#   'rather',
#   'shopping',
#   'http',
#   '//t.co/l0pmmtzlwp',
#   'mystery'],
#  ['ezralevant',
#   'someone',
#   'told',
#   'soccer',
#   'moms',
#   'getting',
#   'pic',
#   'blown',
#   'put',
#   'daughter',
#   "'s",
#   'bedroom',
#   'walls'],
#  ['papcrdoll',
#   's2g',
#   'mentions',
#   'get',
#   'blown',
#   'choice',
#   'deactivate',
#   'leave',
#   'good',
#   'respect',
#   'choices'],
#  ['manutd',
#   'emilymcfcheslop',
#   'wow',
#   'wow',
#   'club',
#   'blown',
#   'money',
#   'fucked',
#   'player',
#   'like',
#   "'d",
#   'pilloried'],
#  ['damn', 'greinke', 'got', 'blown', 'first', 'inning'],
#  ['woke', 'blown', 'lol'],
#  ['aunt', 'marge', "'re", 'blown', 'eheks'],
#  ['troylercraft',
#   'yeah',
#   'worth',
#   'bc',
#   'already',
#   'many',
#   'spammers',
#   'amp',
#   'twitter',
#   'probably',
#   'blown',
#   'every',
#   'second'],
#  ['white',
#   'family',
#   'supposedly',
#   'representing',
#   'america',
#   "'s",
#   'great',
#   'values',
#   'gets',
#   'blown',
#   'horrible',
#   'cgi',
#   'nuclear',
#   'strike',
#   '.....',
#   'lmfaoooo'],
#  ['man', "n't", 'machinegunkelly', 'blown', "'s", 'still', 'underground'],
#  ['mentions', 'blown', 'wtf'],
#  ['thisdayinhistory',
#   '1862',
#   'confederate',
#   'ship',
#   'blown',
#   'crew',
#   'read',
#   'http',
#   '//t.co/iw7elszifz',
#   'via',
#   'history'],
#  ['moment',
#   'ur',
#   'win',
#   'mini',
#   'uhc',
#   'get',
#   'blown',
#   'creeper',
#   'get',
#   'kicked',
#   'flying',
#   '.....',
#   'salty',
#   'rn',
#   '...'],
#  ['libraryeliza',
#   'get',
#   'taylorswift13',
#   "'bump",
#   'approval',
#   'probably',
#   "'s",
#   'blown',
#   'http',
#   '//t.co/kolmzbz1pz',
#   'musicadvisory'],
#  ["'if",
#   'truckload',
#   'soldiers',
#   'blown',
#   'nobody',
#   'panics',
#   'one',
#   'little',
#   'lion',
#   'dies',
#   'everyone',
#   'loses',
#   "mind'",
#   'http',
#   '//t.co/wjntaokdhf'],
#  ['hey',
#   'look',
#   'kash',
#   "'s",
#   'foundation',
#   'live',
#   'today',
#   'got',
#   'blown',
#   'people',
#   'magazine',
#   "'s",
#   'website',
#   'todd',
#   'blake',
#   '...',
#   'http',
#   '//t.co/2fenu1syu6'],
#  ['kaylak369',
#   'got',
#   'last',
#   'month',
#   'went',
#   'ee',
#   'shop',
#   'glad',
#   "n't",
#   'blown',
#   'yet',
#   'http',
#   '//t.co/pgb2bmcfx8'],
#  ['first',
#   'time',
#   'tweet',
#   'blown',
#   'almost',
#   'half',
#   'day',
#   'later',
#   '...',
#   'https',
#   '//t.co/1buf0xm53d'],
#  ["'we\x89ûªre",
#   'blown',
#   'away',
#   'extension',
#   'nothing',
#   'we\x89ûªve',
#   'seen',
#   'many',
#   'options',
#   'one',
#   'https',
#   '//t.co/0yzgw9zbhr',
#   'https',
#   '//t.co/rhtaqjvqn2'],
#  ['theboyofmasks',
#   "'thanks",
#   'letting',
#   'stay',
#   'since',
#   'manor',
#   'blown',
#   '.....',
#   'anyways',
#   'buddy'],
#  ['loner',
#   'diaries',
#   'patterns',
#   'sand',
#   'may',
#   'blown',
#   'away',
#   'photos',
#   'twos',
#   'choked',
#   'flames',
#   '....',
#   'http',
#   '//t.co/ekfaz6wvbz'],
#  ['even',
#   'though',
#   'bsg',
#   'sufficiently',
#   'hyped',
#   'years',
#   'somehow',
#   'delayed',
#   'watching',
#   'utterly',
#   'utterly',
#   'blown',
#   'away'],
#  ['vanessa',
#   "'s",
#   'game',
#   'officially',
#   'blown',
#   'ladies',
#   'gentlemen',
#   '...',
#   'real',
#   'show',
#   'begin',
#   'bb17'],
#  ['guaranteed',
#   'bitten',
#   'mutant',
#   'mosquito',
#   'ankle',
#   'blown',
#   'little',
#   'cunts'],
#  ['things',
#   'pick',
#   'tozlet',
#   'seat|',
#   'butt',
#   'leprosy',
#   'full-blown',
#   'jerkface',
#   'syndrome',
#   'lateral',
#   'lisp',
#   'amp',
#   'toilet',
#   'rickets'],
#  ['kalinandmyles',
#   'kalinwhite',
#   'ig',
#   'blown',
#   'hackers',
#   'need',
#   'stop',
#   'givebackkalinwhiteaccount'],
#  ['luke_winkie',
#   'whoever',
#   'directing',
#   'videos',
#   'needs',
#   'grab',
#   'nicki',
#   'minaj',
#   'someone',
#   'u.s.',
#   'recognition',
#   'minds',
#   'blown'],
#  ['princessduck',
#   'last',
#   'week',
#   'wanted',
#   '6th',
#   'sense',
#   'get',
#   'blown',
#   'far',
#   'good',
#   'james',
#   'could',
#   'win',
#   "'s",
#   'huge',
#   'target',
#   'gone',
#   'soon'],
#  ['orbette', 'like', 'blown', 'amirite'],
#  ['dog\x89ûªs',
#   'blown',
#   'kennel',
#   '\x89ûò',
#   'bloody',
#   'yorkshire',
#   'terrorist'],
#  ['turn', 'espn2', 'get', 'blown'],
#  ['hopefulbatgirl',
#   'went',
#   'beaten',
#   'blown',
#   'next',
#   'thing',
#   'know',
#   'ra',
#   'al',
#   'ghul',
#   'brought',
#   'back',
#   'life',
#   'escaped',
#   '--'],
#  ['thebriankrause',
#   'leos',
#   'ass',
#   'got',
#   'metaphorically',
#   'blown',
#   'piperwearsthepants',
#   'charmed'],
#  ['anarchic_teapot',
#   'boironusa',
#   'zeno001',
#   'glononium',
#   '6c',
#   'also',
#   'helps',
#   'blown',
#   'bashing',
#   'bottle',
#   'nitroglycerin',
#   'book'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full',
#   're\x89û_',
#   'http',
#   '//t.co/y87gi3brlv',
#   'http',
#   '//t.co/1zbhvdcxzs'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full',
#   're\x89û_',
#   'http',
#   '//t.co/blaawhysct',
#   'http',
#   '//t.co/ddr0zjxvqn'],
#  ['son',
#   'daughter',
#   'would',
#   'like',
#   'see',
#   'going',
#   'war',
#   'iran',
#   'come',
#   'back',
#   'body',
#   'bag',
#   'let',
#   'republicans',
#   'know'],
#  ['questergirl',
#   'ditto',
#   'way',
#   'feel',
#   'drank',
#   'vodka',
#   'ice',
#   'would',
#   'body',
#   'bag'],
#  ['handbags',
#   'genuine',
#   'mulberry',
#   'antony',
#   'cross',
#   'body',
#   'messenger',
#   'bag',
#   'dark',
#   'oak',
#   'soft',
#   'buffalo',
#   'leather',
#   'å£279.00end',
#   'date',
#   'w',
#   '...',
#   'http',
#   '//t.co/ftm4rkl8mn'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay',
#   'http',
#   '//t.co/jrxgolnpqw',
#   'http',
#   '//t.co/lin16kvzbn'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay',
#   'http',
#   '//t.co/gggfvo5pb4',
#   'http',
#   '//t.co/nlfr8t3xqm'],
#  ['louis',
#   'vuitton',
#   'cultsierre',
#   'monogram',
#   'shoulder',
#   'bag',
#   'cross',
#   'body',
#   'bag',
#   'http',
#   '//t.co/muf5czqjrl',
#   'http',
#   '//t.co/sslt8esmhy'],
#  ['check',
#   'ameribag',
#   'healthy',
#   'back',
#   'bag',
#   'shoulder',
#   'cross',
#   'body',
#   'backpack',
#   'khaki',
#   'tan',
#   'beige',
#   'nylon',
#   'http',
#   '//t.co/r4k7tylofj',
#   'ebay'],
#  ['photo',
#   'bath',
#   'amp',
#   'body',
#   'works',
#   'cosmetic',
#   'bag',
#   'periwinkle',
#   'blue',
#   'copper',
#   'piping',
#   'along',
#   'top',
#   'four',
#   'corners',
#   '....',
#   'http',
#   '//t.co/a9bnlse6qb'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full',
#   're\x89û_',
#   'http',
#   '//t.co/3pcntczoxv',
#   'http',
#   '//t.co/n0akjm1e4b'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'body',
#   'bag',
#   'hip',
#   'word',
#   'skirt',
#   'blue',
#   'http',
#   '//t.co/lvkoemsq8m',
#   'http',
#   '//t.co/cjirhhh4vj'],
#  ['å¤',
#   'new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'http',
#   '//t.co/uoozxaus26',
#   'http',
#   '//t.co/6mgbizjfgd',
#   'rt',
#   'en\x89û_'],
#  ['tr_jdavis',
#   'bruh',
#   'wan',
#   'na',
#   'fight',
#   "'m",
#   'meet',
#   'cage',
#   'bro',
#   'better',
#   'find',
#   "'re",
#   'dealing',
#   'end',
#   'body',
#   'bag'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'full',
#   'read\x89û_',
#   'http',
#   '//t.co/4fxfllrien',
#   'http',
#   '//t.co/i12nlsr8fk'],
#  ['auth',
#   'louis',
#   'vuitton',
#   'brown',
#   'saumur',
#   '35',
#   'cross',
#   'body',
#   'shoulder',
#   'bag',
#   'monogram',
#   '7.23',
#   '419-3',
#   'full',
#   'read\x89û_',
#   'http',
#   '//t.co/hcdiwe5flc',
#   'http',
#   '//t.co/zlvebeoavg'],
#  ['check',
#   'vintage',
#   'longaberger',
#   'floral',
#   'fabric',
#   'shoulder',
#   'cross',
#   'body',
#   'bag',
#   'brown',
#   'leather',
#   'strap',
#   'http',
#   '//t.co/fb8snrg4hu',
#   'ebay'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'http',
#   '//t.co/zujwuiomb3',
#   'http',
#   '//t.co/gbctmhx7pw'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'body',
#   'bag',
#   'hip',
#   'word',
#   'skirt',
#   'blue',
#   'http',
#   '//t.co/8jymd9ypsj',
#   'http',
#   '//t.co/57pkmmcadg'],
#  ['ìü',
#   'new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'http',
#   '//t.co/uoozxaus26',
#   'http',
#   '//t.co/pw78nbljky',
#   'rt',
#   'en\x89û_'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay',
#   'http',
#   '//t.co/i4aogcsoy5',
#   'http',
#   '//t.co/djiwg9pxv4'],
#  ['new',
#   'women',
#   'handbag',
#   'faux',
#   'leather',
#   'ladies',
#   'shoulder',
#   'tote',
#   'cross',
#   'body',
#   'bag',
#   'large',
#   'satchel',
#   'full',
#   're\x89û_',
#   'http',
#   '//t.co/ncjpgf6znv',
#   'http',
#   '//t.co/gerjau74ey'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'http',
#   '//t.co/zujwuiomb3',
#   'http',
#   '//t.co/iap4lwvqsw'],
#  ['one', 'day', 'heart', 'gone', 'get', 'zipped', 'body', 'bag'],
#  ['handbag',
#   'fashion',
#   'style',
#   'http',
#   '//t.co/ipxpi3me16',
#   'authentic',
#   'louis',
#   'vuitton',
#   'pochette',
#   'bosphore',
#   'shoulder',
#   'cross',
#   'body',
#   'bag\x89û_',
#   'http',
#   '//t.co/rv0fk7q4y5'],
#  ['å_',
#   'new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'http',
#   '//t.co/zujwuiomb3',
#   'http',
#   '//t.co/ykltfj1fnc'],
#  ['handbag',
#   'fashion',
#   'style',
#   'http',
#   '//t.co/hpd3snm6oy',
#   'vintage',
#   'coach',
#   'purse',
#   'camera',
#   'bag',
#   'cross',
#   'body',
#   '9973',
#   '16.99',
#   '0',
#   'bids',
#   '\x89û_',
#   'http',
#   '//t.co/gsmddmu9pu'],
#  ['genuine',
#   'leather',
#   'man',
#   'bag',
#   'messenger',
#   'fit',
#   'ipad',
#   'mini',
#   '4',
#   'tablet',
#   'case',
#   'cross',
#   'body',
#   'air',
#   'jp',
#   'full',
#   'rea\x89û_',
#   'http',
#   '//t.co/rcburzsb2b',
#   'http',
#   '//t.co/ehsfklgri3'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay',
#   'http',
#   '//t.co/vjgr6liaxh',
#   'http',
#   '//t.co/55jr66plov'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'http',
#   '//t.co/zujwuiomb3',
#   'http',
#   '//t.co/cjqq6cgohg'],
#  ['nuu', 'fam', 'fwt', "'m", 'leave', 'body', 'bag'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'full',
#   'read\x89û_',
#   'http',
#   '//t.co/ur7fexszg4',
#   'http',
#   '//t.co/wb8awoblcl'],
#  ['rhee1975',
#   'deliciousvomit',
#   "'m",
#   "'m",
#   'saying',
#   "'re",
#   'lucky',
#   'go',
#   'home',
#   'families',
#   'put',
#   'body',
#   'bag'],
#  ['matt_bez',
#   'oh',
#   "'m",
#   'bagging',
#   'body',
#   'bangin',
#   "'m",
#   'saying',
#   "'s",
#   'going',
#   'get',
#   'rose'],
#  ['ohmyloz', 'rondarousey', 'bagging', 'body', "'s", 'smoking', 'hot'],
#  ['drake', 'really', 'body', 'bagging', 'meek'],
#  ['fuckyeahcarey',
#   'bornverified',
#   'drake',
#   'killing',
#   'dude',
#   'tea',
#   'bagging',
#   'dead',
#   'body',
#   'point'],
#  ['meekmill',
#   'w',
#   'rec',
#   'k',
#   'league',
#   'ball',
#   'drake',
#   'olympic',
#   'level',
#   'body',
#   'bagging',
#   'like',
#   'career',
#   'nothing',
#   'trollingtilmeekdiss'],
#  ['idgaf',
#   'tough',
#   'canada',
#   'north',
#   'philly',
#   'meek',
#   'acting',
#   'like',
#   'bitch',
#   'amp',
#   'drake',
#   'body',
#   'bagging',
#   'ass',
#   'tracks'],
#  ['yankees', 'body', 'bagging', 'mfs'],
#  ['broseidonrex',
#   'dapurplesharpie',
#   'skimmed',
#   'twitter',
#   'missed',
#   'body',
#   'bagging'],
#  ['g+',
#   '+https',
#   '//t.co/dodxi41y1cåêis',
#   'body',
#   'bagging',
#   'lyrically',
#   'https',
#   '//t.co/hlmyaanrc9'],
#  ['bomairinge', 'elutranscendent', 'straight', 'body', 'bagging'],
#  ['body', 'bagging', 'bitches', 'http', '//t.co/afssgpnzwi'],
#  ['better',
#   'feeling',
#   'seeing',
#   'stage',
#   'day',
#   'ones',
#   '......',
#   '22',
#   'year',
#   'friendships',
#   'still',
#   'body',
#   'bagging',
#   'mics',
#   'together'],
#  ['mopheme',
#   'bigstar',
#   'johnson',
#   'problem',
#   'game',
#   'body',
#   'bagging',
#   'niggas',
#   'vuzuhustle'],
#  ['body',
#   'bagging',
#   'today',
#   '...',
#   '4got',
#   'post',
#   'score',
#   'http',
#   '//t.co/81g18wsauk'],
#  ['editaxohaze',
#   'let',
#   'bagging',
#   'body',
#   "'s",
#   'begin',
#   'lol',
#   'ai',
#   "n't",
#   'cuffed',
#   'yet',
#   "n't",
#   'bad'],
#  ...]

# %% [markdown]
# # 1. Training Your Own Model - Word2Vec

# %%
trained = Word2Vec(data,min_count=2,sg=1,window=2)

# %%
trained.wv.similar_by_word('earthquake')
# Out:
# [('real', 0.9987149834632874),
#  ('drowned', 0.9986874461174011),
#  ('exploded', 0.9986623525619507),
#  ('terrorist', 0.9986556172370911),
#  ('end', 0.9986073970794678),
#  ('area', 0.9985902905464172),
#  ('4', 0.9985886812210083),
#  ('great', 0.9985824227333069),
#  ('lol', 0.9985775947570801),
#  ('might', 0.9985739588737488)]

# %%
trained.wv.get_vector('earthquake')
# Out:
# array([-0.16769353,  0.0178898 ,  0.09899525, -0.0830802 , -0.11643381,
#        -0.36784244,  0.12461206,  0.4808725 , -0.11617592, -0.2423674 ,
#        -0.13377012, -0.14965281, -0.08578119,  0.11691414, -0.07421583,
#        -0.1987719 ,  0.10240614, -0.11359329, -0.21820137, -0.4115698 ,
#         0.11928599, -0.00362729, -0.00054583, -0.07060292, -0.00496722,
#        -0.00809798, -0.05259161, -0.16835733, -0.09196518,  0.1325324 ,
#         0.26731208, -0.03899104,  0.1660759 , -0.05590305,  0.05858663,
#         0.01186336,  0.0686678 , -0.29383785,  0.10122518, -0.29155186,
#        -0.1623201 , -0.10136265, -0.03324253,  0.10868829,  0.13907722,
#        -0.16552728, -0.03279367, -0.00907618,  0.26236132,  0.1579492 ,
#         0.11329678, -0.12990919, -0.16546679,  0.0033845 , -0.12808104,
#         0.10872381,  0.11732896,  0.10231113,  0.03241859, -0.04672313,
#         0.1170281 ,  0.01734778, -0.12817629,  0.08112647, -0.24921827,
#         0.35466588, -0.07161692,  0.1396113 , -0.30108467,  0.3442483 ,
#        -0.21306169,  0.14918217,  0.3095598 , -0.14670129,  0.240487  ,
#         0.0379799 ,  0.03448381, -0.08809655, -0.17808358,  0.08828575,
#        -0.05203504,  0.00555357, -0.28996927,  0.28424612,  0.0740476 ,
#        -0.04040613,  0.01893866,  0.20952107,  0.26102015,  0.18984102,
#         0.16187921, -0.06196589,  0.11064041, -0.0279166 ,  0.21842547,
#        -0.0232722 ,  0.12190695, -0.3474324 ,  0.14439419, -0.07272185],
#       dtype=float32)

# %% [markdown]
# # 2. Word2Vec - embeddings

# %%
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
w2v = api.load('word2vec-google-news-300')

# %%
w2v.similar_by_word('celebrate')
# Out:
# [('celebrating', 0.8155195116996765),
#  ('celebrated', 0.7704004049301147),
#  ('celebration', 0.7418112754821777),
#  ('commemorate', 0.7094196081161499),
#  ('celebrates', 0.6778473258018494),
#  ('Celebrate', 0.6725128293037415),
#  ('Celebrating', 0.6519656777381897),
#  ('celebrations', 0.6102868914604187),
#  ('cele_brate', 0.5931569337844849),
#  ('rejoice', 0.5903198719024658)]

# %%
w2v.get_vector('celebrate')
# Out:
# array([-4.34570312e-02, -1.35742188e-01,  1.18164062e-01,  2.06054688e-01,
#         2.33398438e-01, -3.18359375e-01,  7.56835938e-02, -2.65625000e-01,
#         7.42187500e-02,  7.76367188e-02, -2.71484375e-01, -7.27539062e-02,
#        -2.84423828e-02,  3.78906250e-01,  2.94921875e-01,  7.37304688e-02,
#         1.25000000e-01,  2.22656250e-01,  2.39257812e-01, -1.33789062e-01,
#         1.47460938e-01,  2.91015625e-01,  2.10937500e-01, -2.49023438e-01,
#         1.76757812e-01, -5.06591797e-03,  1.71875000e-01,  4.17480469e-02,
#         2.41210938e-01, -1.57226562e-01,  2.03125000e-01,  7.26318359e-03,
#         3.08227539e-03,  1.12792969e-01, -1.34765625e-01, -1.23535156e-01,
#         2.55859375e-01, -3.37890625e-01,  2.61718750e-01,  2.13867188e-01,
#         2.73437500e-02, -7.56835938e-03,  2.77099609e-02,  9.86328125e-02,
#         2.05078125e-01, -1.34765625e-01, -3.35937500e-01,  5.39550781e-02,
#        -1.98974609e-02,  3.49609375e-01, -2.12402344e-02,  2.39257812e-01,
#         2.46093750e-01,  1.78710938e-01, -7.37304688e-02, -7.71484375e-02,
#        -1.41601562e-01, -2.23632812e-01, -1.20117188e-01, -2.43164062e-01,
#        -1.56250000e-02,  5.34667969e-02, -6.93359375e-02, -2.83203125e-01,
#         1.11816406e-01,  4.02832031e-02, -7.12890625e-02, -1.92871094e-02,
#         3.83300781e-02,  2.61718750e-01,  2.66113281e-02, -9.13085938e-02,
#         9.42382812e-02, -1.48437500e-01,  1.20605469e-01, -2.47070312e-01,
#         6.07910156e-02, -8.34960938e-02, -1.15966797e-02,  2.59765625e-01,
#        -3.51562500e-01, -2.79296875e-01, -4.05273438e-02,  8.65936279e-04,
#        -2.57812500e-01, -6.54296875e-02, -1.68457031e-02, -1.59179688e-01,
#         9.22851562e-02,  2.83203125e-01,  1.74804688e-01, -8.39843750e-02,
#        -2.78320312e-02, -1.10351562e-01,  3.73535156e-02,  8.98437500e-02,
#         1.25000000e-01,  9.96093750e-02, -2.57568359e-02,  5.78613281e-02,
#         1.00585938e-01,  5.12695312e-02,  2.71484375e-01,  1.90429688e-01,
#         7.91015625e-02, -1.42578125e-01,  1.56250000e-01, -1.18164062e-01,
#        -1.97753906e-02,  2.39257812e-01, -2.96020508e-03,  2.65625000e-01,
#         7.42187500e-02,  5.05371094e-02, -1.48437500e-01,  1.03027344e-01,
#         1.13281250e-01, -3.06640625e-01, -9.64355469e-03, -1.59179688e-01,
#         2.19726562e-01,  1.44653320e-02, -5.46875000e-02, -2.30712891e-02,
#         8.00781250e-02, -9.57031250e-02,  2.07031250e-01, -1.73828125e-01,
#        -9.42382812e-02,  1.66320801e-03,  1.01562500e-01,  2.75878906e-02,
#         7.08007812e-02, -5.22460938e-02,  1.41601562e-01,  4.10156250e-01,
#        -5.76782227e-03,  2.98828125e-01, -6.15234375e-02,  8.20312500e-02,
#        -1.58203125e-01,  1.58203125e-01,  1.03149414e-02, -2.21679688e-01,
#        -1.25885010e-03,  2.32421875e-01,  1.75781250e-01,  1.42578125e-01,
#        -1.50390625e-01, -6.20117188e-02, -3.22265625e-02,  9.37500000e-02,
#        -4.85839844e-02,  2.87109375e-01,  1.31835938e-01, -4.49218750e-02,
#         1.26953125e-01, -8.34960938e-02, -1.18652344e-01, -4.27734375e-01,
#        -2.15820312e-01,  1.73339844e-02, -1.02539062e-01, -3.22265625e-02,
#         5.74218750e-01, -4.21875000e-01,  1.36718750e-01, -4.78744507e-04,
#         1.86767578e-02,  8.59375000e-02, -2.34375000e-01, -2.41699219e-02,
#         2.35595703e-02, -9.15527344e-03,  1.47460938e-01,  1.46484375e-01,
#         1.23535156e-01,  7.03125000e-02, -1.57165527e-03,  4.51660156e-02,
#        -1.76757812e-01, -1.53320312e-01,  8.49609375e-02, -1.46484375e-01,
#        -2.50000000e-01, -1.71875000e-01, -1.09863281e-01,  4.32128906e-02,
#         6.44531250e-02,  1.77734375e-01, -1.36108398e-02, -1.84326172e-02,
#        -2.83203125e-02,  9.81445312e-02, -2.57812500e-01, -1.72851562e-01,
#        -5.27343750e-02,  2.41210938e-01, -8.15429688e-02, -5.78613281e-02,
#        -6.00585938e-02, -2.81982422e-02, -2.77343750e-01, -1.42578125e-01,
#         2.00195312e-02,  5.00488281e-02, -1.24511719e-01,  2.11914062e-01,
#        -1.67968750e-01, -3.75976562e-02, -1.14257812e-01,  4.57031250e-01,
#         5.02929688e-02,  4.80957031e-02,  1.22680664e-02,  1.91406250e-01,
#         2.01171875e-01, -1.45874023e-02,  1.84570312e-01,  4.10156250e-02,
#         3.73535156e-02, -1.72851562e-01,  4.22363281e-02,  1.16699219e-01,
#         5.37109375e-02, -1.83105469e-02, -1.01074219e-01,  6.39648438e-02,
#         1.40625000e-01,  9.66796875e-02, -1.09375000e-01,  1.56250000e-01,
#        -1.34765625e-01,  1.72851562e-01,  3.18359375e-01, -2.23632812e-01,
#        -1.37695312e-01, -6.44531250e-02,  9.22851562e-02, -4.34570312e-02,
#        -4.06250000e-01, -5.78613281e-02, -1.95312500e-01,  1.04492188e-01,
#        -2.67578125e-01,  5.81054688e-02, -1.21093750e-01,  1.46484375e-01,
#         2.46582031e-02, -3.22265625e-01, -1.97265625e-01,  2.53906250e-01,
#         6.00585938e-02,  1.14135742e-02,  6.34765625e-02, -6.54296875e-02,
#        -8.34960938e-02,  3.30078125e-01, -1.84570312e-01,  1.13281250e-01,
#        -4.33593750e-01, -4.27246094e-02, -2.04101562e-01, -4.61425781e-02,
#         2.50000000e-01,  1.24023438e-01,  2.03125000e-01,  1.96289062e-01,
#        -3.32031250e-02,  1.40625000e-01,  6.73828125e-02,  9.52148438e-02,
#         1.79687500e-01, -1.20117188e-01,  4.64843750e-01, -3.02734375e-01,
#        -7.91015625e-02, -2.41699219e-02, -2.16796875e-01, -4.66796875e-01,
#        -4.71191406e-02,  3.97949219e-02, -2.11914062e-01,  2.66113281e-02,
#        -6.44531250e-02,  9.03320312e-02, -1.55273438e-01,  1.66015625e-01,
#        -1.28906250e-01, -1.68457031e-02,  2.65625000e-01,  1.78710938e-01,
#        -1.87500000e-01,  7.61718750e-02, -1.80664062e-01, -3.28125000e-01,
#        -4.61425781e-02, -1.74804688e-01,  2.55859375e-01, -9.96093750e-02],
#       dtype=float32)

# %% [markdown]
# # 3. Loading GloVe vector

# %%
zipped_folder = zipfile.ZipFile('glove.6B.zip')

# %%
zipped_folder.filelist
# Out:
# [<ZipInfo filename='glove.6B.50d.txt' compress_type=deflate filemode='-rw-rw-r--' file_size=171350079 compress_size=69182485>,
#  <ZipInfo filename='glove.6B.100d.txt' compress_type=deflate filemode='-rw-rw-r--' file_size=347116733 compress_size=134300389>,
#  <ZipInfo filename='glove.6B.200d.txt' compress_type=deflate filemode='-rw-rw-r--' file_size=693432828 compress_size=264336891>,
#  <ZipInfo filename='glove.6B.300d.txt' compress_type=deflate filemode='-rw-rw-r--' file_size=1037962819 compress_size=394362180>]

# %%
GloVe_data = zipped_folder.extract('glove.6B.50d.txt')

# %%
for i in open(GloVe_data, encoding="utf8"):
    print("Below is the word: ")
    print(i.split(" ")[0])
    print('\n')
    print("Below is the Vector: ")
    print(i.split(" ")[1:])
    
    break
# Out:
# Below is the word:
# the
#
#
# Below is the Vector:
# ['0.418', '0.24968', '-0.41242', '0.1217', '0.34527', '-0.044457', '-0.49688', '-0.17862', '-0.00066023', '-0.6566', '0.27843', '-0.14767', '-0.55677', '0.14658', '-0.0095095', '0.011658', '0.10204', '-0.12792', '-0.8443', '-0.12181', '-0.016801', '-0.33279', '-0.1552', '-0.23131', '-0.19181', '-1.8823', '-0.76746', '0.099051', '-0.42125', '-0.19526', '4.0071', '-0.18594', '-0.52287', '-0.31681', '0.00059213', '0.0074449', '0.17778', '-0.15897', '0.012041', '-0.054223', '-0.29871', '-0.15749', '-0.34758', '-0.045637', '-0.44251', '0.18785', '0.0027849', '-0.18411', '-0.11514', '-0.78581\n']

# %%
embedding_vectors = {}
for i in open(GloVe_data, encoding="utf8"):
    word = i.split(" ")[0]
    embedding = i.split(" ")[1:]
    embedding_vectors[word] = embedding
# Out:
# the
# ['0.418', '0.24968', '-0.41242', '0.1217', '0.34527', '-0.044457', '-0.49688', '-0.17862', '-0.00066023', '-0.6566', '0.27843', '-0.14767', '-0.55677', '0.14658', '-0.0095095', '0.011658', '0.10204', '-0.12792', '-0.8443', '-0.12181', '-0.016801', '-0.33279', '-0.1552', '-0.23131', '-0.19181', '-1.8823', '-0.76746', '0.099051', '-0.42125', '-0.19526', '4.0071', '-0.18594', '-0.52287', '-0.31681', '0.00059213', '0.0074449', '0.17778', '-0.15897', '0.012041', '-0.054223', '-0.29871', '-0.15749', '-0.34758', '-0.045637', '-0.44251', '0.18785', '0.0027849', '-0.18411', '-0.11514', '-0.78581\n']

# %%
embedding_vectors.get('celebrate')
# Out:
# ['0.12191',
#  '0.81221',
#  '-1.0196',
#  '-0.65983',
#  '1.2592',
#  '-1.1492',
#  '-0.9591',
#  '0.29959',
#  '0.10093',
#  '0.48487',
#  '-0.1485',
#  '-0.71627',
#  '0.44745',
#  '-0.11944',
#  '0.79406',
#  '-0.11197',
#  '0.088971',
#  '-0.59892',
#  '-0.55688',
#  '-0.10685',
#  '0.48526',
#  '0.010769',
#  '-0.53309',
#  '-0.04685',
#  '0.54524',
#  '-0.63864',
#  '-1.1066',
#  '-0.75267',
#  '0.1718',
#  '-0.54662',
#  '1.6035',
#  '1.9806',
#  '-1.3012',
#  '0.26014',
#  '-0.4527',
#  '-0.32813',
#  '0.45034',
#  '0.083061',
#  '-0.91002',
#  '0.32949',
#  '-0.74186',
#  '-0.376',
#  '-0.94503',
#  '-0.70876',
#  '0.16447',
#  '0.75677',
#  '-0.25292',
#  '-0.77441',
#  '-0.65655',
#  '-0.55295\n']

# %% [markdown]
# # 4. Simple Chatbot using TFIDF

# %%
df = pd.read_csv('Botdata.csv',encoding='cp1252')

# %%
df.Responses.value_counts(normalize=True)
# Out:
# Link: Neural Nets wiki                       0.143357
# Link: Machine Learning wiki                  0.139860
# Transferring the request to your PM          0.129371
# I hope I was able to assist you, Good Bye    0.125874
# Link: Olympus wiki                           0.122378
# Hello! how can i help you ?                  0.115385
# Please use respectful words                  0.115385
# I am your virtual learning assistant         0.108392
# Name: Responses, dtype: float64

# %%
df['Pattern'].iloc[7]
# Out:
# 'listen'

# %%
WNL = WordNetLemmatizer()

# %%
[WNL.lemmatize(i) for i in word_tokenize(df['Pattern'].iloc[281])]
# Out:
# ['Please', 'get', 'some', 'live', 'person', 'to', 'clear', 'my', 'doubt']

# %%
data = []
def clean_text(x):
    for i in x:
        data.append(' '.join([''.join(WNL.lemmatize(w,pos='v')) for w in word_tokenize(i.lower()) if w not in string.punctuation]))

# %%
clean_text(df['Pattern'])

# %%
data
# Out:
# ['hi',
#  'how be you',
#  'hello there',
#  'hello',
#  'whats up',
#  'hey',
#  'yo',
#  'listen',
#  'please help me',
#  'hi there',
#  'hello bot',
#  'whats up for today',
#  'hello guy i need a help',
#  'hey there',
#  'i have a quick question',
#  'how to start',
#  'online',
#  'hey ya',
#  'talk to you for first time',
#  'anyone there',
#  'i be here to get help',
#  'someone help me please',
#  'ello',
#  'wassuppp',
#  'whats happen around the portal',
#  'i have few quick question',
#  'i need a help',
#  'there',
#  'what be your name',
#  'who be you',
#  'how do they call you',
#  'do i know you',
#  'who be there',
#  'who be you',
#  'your name please',
#  'may i know your name',
#  'speak up',
#  'be you a human',
#  'do you answer question',
#  'who be learn assistant',
#  'who be support assistant',
#  'any assistant',
#  'whos that i be speak to',
#  'may i know who you be',
#  'who be speak',
#  'be you a bot or a human',
#  'who be i speak to a bot or a person',
#  'how do i call you',
#  'can i call you vla',
#  'be you my teacher',
#  'they call you with what',
#  'i would like to know about you',
#  'you be what',
#  'thank you',
#  'thank',
#  'cya',
#  'see you',
#  'later',
#  'see you later',
#  'goodbye',
#  'i be leave',
#  'have a good day',
#  'you help me',
#  'thank a lot',
#  'thank a ton',
#  'you be the best',
#  'great help',
#  'too good',
#  'you be a good learn buddy',
#  'ok i be good',
#  "alright i 'm good",
#  'thank for help',
#  'doubt clear',
#  'exit',
#  'quit clear',
#  'that ’ s a wrap',
#  'bye bye',
#  'ty',
#  'i think you clear my doubt',
#  'you can answer well',
#  'you be a good replacement for humans to clarify doubt',
#  'i think i be good with your answer it seem to be clear and i can do this now',
#  'i be not able to understand svm',
#  'explain me how machine learn work',
#  'i be not able to understand naive bay',
#  'i be not able to understand logistic regression',
#  'i be not able to understand ensemble techb=niques',
#  'i be not able to understand knn',
#  'i be not able to understand knn imputer',
#  'i be not able to understand cross validation',
#  'i be not able to understand boost',
#  'i be not able to understand random forest',
#  'i be not able to understand ada boost',
#  'i be not able to understand gradient boost',
#  'machine learn',
#  'ml',
#  'sl',
#  'supervise learn',
#  'knn',
#  'logistic regression',
#  'regression',
#  'classification',
#  'naive bay',
#  'nb',
#  'ensemble techniques',
#  'bag',
#  'boost',
#  'ada boost',
#  'ada',
#  'gradient boost',
#  'hyper parameters',
#  'what be deep learn',
#  'unable to understand deep learn',
#  'explain me how deep learn work',
#  'i be not able to understand deep learn',
#  'not able to understand neural net',
#  'very diffult to understand neural net',
#  'unable to understand neural net',
#  'ann',
#  'artificial intelligence',
#  'artificial neural network',
#  'weight',
#  'activation function',
#  'hide layer',
#  'softmax',
#  'sigmoid',
#  'relu',
#  'otimizer',
#  'forward propagation',
#  'backward propagation',
#  'epochs',
#  'epoch',
#  'what be an epoch',
#  'adam',
#  'sgd',
#  'what be ai',
#  'can you think',
#  'how do machine think',
#  'perceptron',
#  'what be early stop',
#  'olympus',
#  'explain me how olympus work',
#  'i be not able to understand olympus',
#  'olympus window not work',
#  'no access to olympus',
#  'unable to see link in olympus',
#  'no link visible on olympus',
#  'whom to contact for olympus',
#  'lot of problem with olympus',
#  'olypus be not a good tool',
#  'lot of problems with olympus',
#  'how to use olympus',
#  'teach me olympus',
#  'portal not work',
#  'give me portal link',
#  'olympus portal',
#  'pg portal',
#  'course portal',
#  'poc for olympus portal',
#  'help me on olympus portal',
#  'tell me how this pg work',
#  'may i have the wiki page for this pg course',
#  'there be an ongoing problem with the site be it down',
#  'do you have wikipedia for this pg',
#  'which site help in display the course',
#  'do i need to login to use this course',
#  'be there any portal to display all the course',
#  'where do i see my rank',
#  'where shall i see my mark',
#  'what the hell be you talk about',
#  'bloody stupid bot',
#  'do you think you be very smart',
#  'screw you',
#  'i hate you',
#  'you be stupid',
#  'jerk',
#  'you be a joke',
#  'useless piece of shit',
#  'get lose',
#  'you stupid',
#  'dont talk like an idiot',
#  'do you have sense',
#  'senseless creature',
#  'shut your mouth',
#  'dont speak like a dummy',
#  'you stupid dummy',
#  'shut up',
#  'you deserve bad word and bad shit only',
#  'shut your useless responses',
#  'you be just a junk that have no value',
#  'bloody',
#  'stupid',
#  'shit',
#  'dum',
#  'i say shutttt upppp',
#  'get out of my way',
#  'you be a complete mess',
#  'messy creature',
#  'my problem be not solve',
#  'you do not help me',
#  'not a good solution',
#  'bad solution',
#  'not good solution',
#  'no help',
#  'waste my time',
#  'useless bot',
#  'create a ticket',
#  'i dont see a solution',
#  'where be the solution',
#  'connect me to a human',
#  'want to talk to a person',
#  'this be not an answer',
#  'its not a solution',
#  'this be not a solution',
#  'please push it to a human',
#  'i do not want to talk to a bot',
#  'do not connect to a bot',
#  'someone please answer my question',
#  'can you please connect me to someone who can talk',
#  'i would need a better help',
#  'i need my query to be manually handle',
#  'i would need a real assistant',
#  'this aint help me get to the solution',
#  'can i get a better solution',
#  'can i get a better answer',
#  'i can not talk to a bot i need human intervention',
#  'i be not intrested in talk to an automate computer',
#  'somebody please help me',
#  'good morning',
#  'good afternoon',
#  'good even',
#  'someone there',
#  'your be',
#  'you be',
#  'be you their assistant',
#  'what be you',
#  'whats your name',
#  'how be i suppose to call you',
#  'my doubt be clear',
#  'my issue be rectify',
#  'im good',
#  'its clear',
#  'all clear',
#  'perfect this be what i need',
#  'this clear my doubt',
#  'what be svm that be the support vector machine',
#  'what be ml',
#  'what be machine learn',
#  'its about machine learn',
#  'its about ml',
#  'ml technique doubt',
#  'i have doubt on ml',
#  'i have doubt on ml techniques',
#  'i have doubt on algorithms',
#  'ml algorithms doubt',
#  'can you help me understand the ml algorithms',
#  'i just cant understand the ann',
#  'what be ann',
#  'ann',
#  'what do ann do',
#  'advantage of ann',
#  'be ann efficient',
#  'what be universal approximation',
#  'neural network',
#  'what be nn',
#  'i would like some support on nn',
#  'i would like some support on ann',
#  'somebody please help me understand ann',
#  'someone can explain how the portal work',
#  'where be the aiml portal',
#  'where do i see the course materials',
#  'where do i see the record of the mentor session',
#  'what be the feature of the olympus portal',
#  'how do i access the portal to learn',
#  'shut your answer right now',
#  'shitty bot',
#  'just cant stand your stupid responses',
#  'get lose you idiotic bot',
#  'can someone please help me with better answer',
#  'be there a human to clear my doubt',
#  'please send in some human to clear my doubt',
#  'please get some live person to clear my doubt',
#  'your answer be not clear and correct i need help',
#  'i need better answer to my question',
#  'these be not clear answer',
#  'you please connect this conversation to a live human conversation']

# %%
tf = TfidfVectorizer()

# %%
tfidf = tf.fit_transform(data)

# %%
tfidf.toarray().shape
# Out:
# (286, 291)

# %%
LE = LabelEncoder()

# %%
X = tfidf.toarray()
y = LE.fit_transform(df['Responses'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
RFC = RandomForestClassifier(n_estimators=200)

# %%
RFC.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
pred = RFC.predict(X_test)

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52        11
#            1       0.62      0.62      0.62         8
#            2       0.27      0.75      0.40         4
#            3       0.83      0.77      0.80        13
#            4       0.73      0.42      0.53        19
#            5       1.00      0.92      0.96        12
#            6       0.44      1.00      0.62         4
#            7       0.67      0.53      0.59        15
#
#     accuracy                           0.64        86
#    macro avg       0.63      0.70      0.63        86
# weighted avg       0.70      0.64      0.65        86

# %%
def pred(x):
    data=[]
    data.append(' '.join([''.join(WNL.lemmatize(w,pos='v')) for w in word_tokenize(x.lower()) if w not in string.punctuation]))
    x = tf.transform(data)
    pred = RFC.predict(x.toarray())
    print(LE.inverse_transform(pred))

# %%
pred("What is your name")
# Out:
# ['I am your virtual learning assistant']
